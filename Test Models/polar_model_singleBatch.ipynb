# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, concatenate
from tensorflow.keras.models import Model

# %% [markdown]
# GPU settings.

# %%
import os
os.environ['TF_METAL_ENABLE_MPS'] = '1'

# %% [markdown]
# Now, in order to use the GPU, I need to run my code inside:
#
#
# `with tf.device('/device:GPU:0'):`
#
#
# Exactly as shown in the example.

# %% [markdown]
# Function to plot history recordings data.

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %% [markdown]
# Generator.

# %%
def polar_generator(batchsize,grid=(10,10),noise=.002,flat=True):
  while True:
    x = np.random.rand(batchsize)
    y = np.random.rand(batchsize)
    out = np.zeros((batchsize,grid[0],grid[1]))
    xc = (x*grid[0]).astype(int)
    yc = (y*grid[1]).astype(int)
    for b in range(batchsize):
      out[b,xc[b],yc[b]] = 1
    #compute rho and theta and add some noise
    rho = np.sqrt(x**2+y**2) + np.random.normal(scale=noise)
    theta = np.arctan(y/np.maximum(x,.00001)) + np.random.normal(scale=noise)
    if flat:
      out = np.reshape(out,(batchsize,grid[0]*grid[1]))
    yield ((theta,rho),out)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0
# 2023-01-10 12:50:06.800980: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-10 12:50:06.801000: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# Train and test arrays from generator.

# %%
import itertools
import numpy as np
from sklearn.model_selection import train_test_split

train_gen = itertools.islice(polar_generator(batchsize=1, grid=(10,10)), 100000)
#test_gen = itertools.islice(polar_generator(batchsize=1, grid=(10,10)), 50000) #should be validation set, and have the same elements of train_set
#print(next(gen))
print(type(train_gen))
"""
Before the error, the batchsize was 1
"""
# Out:
# <class 'itertools.islice'>
# '\nBefore the error, the batchsize was 1\n'

# %% [markdown]
# Shape check.

# %%
train = list(train_gen)
#test = list(test_gen)

# %% [markdown]
# Array conversion.

# %%
X_train = np.array([x for x, y in train])
y_train = np.array([array for x, y in train for array in y]) # for label in array])
"""
X_test = np.array([x for x, y in test])
y_test = np.array([array for x, y in test for array in y]) # for label in array])
"""
# Out:
# '\nX_test = np.array([x for x, y in test])\ny_test = np.array([array for x, y in test for array in y]) # for label in array])\n'

# %% [markdown]
# Array shape check.

# %%
print(X_train.shape)
print(y_train.shape)
"""
print(X_test.shape)
print(y_test.shape)
"""
# Out:
# (100000, 2, 1)
# (100000, 100)
# '\nprint(X_test.shape)\nprint(y_test.shape)\n'

# %% [markdown]
# ### Models

# %% [markdown]
# #### Model 1

# %%
# Working model_1 
# Accuracy on validation = 24% 
# Param = 3410
# Batch size = 64
# Generator Batchsize = 1
###################
# Working model_1 
# Accuracy on validation = 31% 
# Param = 3410
# Batch size = 32
# Generator Batchsize = 10

input_layer = Input(shape=(2,))
x = Dense(20, activation='relu')(input_layer)
x = Dense(30, activation='relu')(x)
x = Dense(20, activation='relu')(x)
output_layer = Dense(100,activation='relu')(x)

model = Model(input_layer,output_layer)
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
model.summary()

# %% [markdown]
# #### Model 2

# %%
#  model_2 
# Accuracy on validation = ?? 
# Param = 2405
# Batch size = 64

input_layer = Input(shape=(10,2)) # If we go back to batchsize of 1 of the generator, we need input shape=(2,)
x = Dense(10, activation='relu')(input_layer)
x = Dense(30, activation='relu')(x)
x = Dense(20, activation='relu')(x)
x = Dense(10, activation='relu')(x)
output_layer = Dense(100,activation='softmax')(x)

mymodel = Model(input_layer,output_layer)

model = Model(input_layer,output_layer)
model.compile(optimizer="SGD", loss='mse', metrics=['accuracy'])
model.summary()

# %% [markdown]
# #### Model 3

# %%
# Model 3 - Working
# Epocs = 10
# Accuracy on validation = 0.7183
# Param = 2290
# Batch size = 32
# Generator Batchsize = 1
########################
#WITHOUT Flatten layer
# accuracy = 47%
# batch size = 128
# generator batchsize = 10
########################



from keras.layers import Input, Dense, Dropout, Flatten

input_layer = Input(shape=(10,2))
#x = Flatten()(input_layer)
x = Dense(10, activation='relu')(input_layer)
x = Dense(30, activation='relu')(x)
x = Dense(20, activation='relu')(x)
x = Dense(10, activation='relu')(x)
output_layer = Dense(100, activation='sigmoid')(x)

model = Model(input_layer, output_layer)
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %% [markdown]
# #### Model 4

# %%
# Model 4 - Working
# Epocs = 10
# Accuracy on validation = 20%
# Param = 3520
# Batch size = 64
# Generator Batchsize = 10
########################
# This one overfits -> may be improved

from keras.layers import Input, Dense, Dropout, Flatten

input_layer = Input(shape=(10,2))
#x = Flatten()(input_layer)
x = Dense(10, activation='relu')(input_layer)
x = Dense(50, activation='relu')(x)
x = Dense(30, activation='relu')(x)
x = Dense(10, activation='relu')(x)
output_layer = Dense(100, activation='sigmoid')(x)

model = Model(input_layer, output_layer)
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %% [markdown]
# #### Model 5

# %%
# Model 5 - Working
# Epocs = 10
# Accuracy on validation = 89%
# Param = 2290
# Batch size = 64
# Generator Batchsize = 10
########################

from keras.layers import Input, Dense, Dropout, Flatten

input_layer = Input(shape=(10,2))
#x = Flatten()(input_layer)
x = Dense(10, activation='tanh')(input_layer)
x = Dense(30, activation='tanh')(x)
x = Dense(20, activation='tanh')(x) 
x = Dense(10, activation='relu')(x)
output_layer = Dense(100, activation='softmax')(x)

model = Model(input_layer, output_layer)
model.compile(optimizer="adam", loss='mse', metrics=['accuracy'])
model.summary()

# %%
print(history.history["val_accuracy"])
# Out:
# [0.026760002598166466, 0.13736000657081604, 0.3551400303840637, 0.47482001781463623, 0.5557000637054443, 0.5978000164031982, 0.7075400352478027, 0.736240029335022, 0.7611000537872314, 0.7588000297546387, 0.7754400372505188, 0.7990400791168213, 0.8028400540351868, 0.8154400587081909, 0.8356600403785706, 0.8194600343704224, 0.8296000361442566, 0.8338400721549988, 0.8455800414085388, 0.8562200665473938, 0.857900083065033, 0.8621000647544861, 0.8596400618553162, 0.8754200339317322, 0.8583800792694092, 0.8646600842475891, 0.8641600608825684, 0.8833000659942627, 0.8725600838661194, 0.8816800713539124, 0.8870600461959839, 0.8784400820732117, 0.8838200569152832, 0.8877600431442261, 0.8896000385284424, 0.8857000470161438, 0.89354008436203, 0.890440046787262, 0.890440046787262, 0.9013000726699829, 0.897580087184906, 0.8988000750541687, 0.8887800574302673, 0.9017800688743591, 0.9046000838279724, 0.9036400318145752, 0.9015800356864929, 0.8934400677680969]

# %%
plot_history(history)

# %% [markdown]
# #### Model 6

# %%
# Model 6 - Working
# Epocs = 10
# Accuracy on validation = 89%
# Param = 2290
# Batch size = 64
# Generator Batchsize = 10
########################

from keras.layers import Input, Dense, Dropout, Flatten

input_layer = Input(shape=(2,))
print(input_layer.shape)
#x = Flatten()()
x = Dense(10, activation='tanh')(input_layer)
x = Dense(30, activation='tanh')(x)
#x = Dense(20, activation='tanh')(x) 
x = Dense(10, activation='relu')(x)
#x = Reshape((-1, input_layer.shape[2]))(x)
output_layer = Dense(100, activation='softmax')(x)

print(model.output_shape)

model = Model(input_layer, output_layer)
model.compile(optimizer="adam", loss='mse', metrics=['accuracy'])
model.summary()

# %%
plot_history(history)

# %% [markdown]
# #### Model 7 - Test Sequential

# %%
# Batch 32
# Param 4964
# Accuracy 0.91333

from keras.models import Sequential
from keras.layers import LeakyReLU, BatchNormalization
from keras import regularizers

model = Sequential([
    Dense(16, activation='relu', input_shape=(2,)),
    Dense(32, activation='tanh'), #, kernel_regularizer=regularizers.l2(0.0001)),
    Dense(16, activation='tanh'),
    Dense(32, activation=LeakyReLU(alpha=0.1)),# , kernel_regularizer=regularizers.l2(0.001)),
    Dense(100, activation='softmax')
])

model.compile(optimizer="adam", loss='mse', metrics=['accuracy'])
#model.optimizer(lr=0.001)
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_237 (Dense)           (None, 16)                48
#
#  dense_238 (Dense)           (None, 32)                544
#
#  dense_239 (Dense)           (None, 16)                528
#
#  dense_240 (Dense)           (None, 32)                544
#
#  dense_241 (Dense)           (None, 100)               3300
#
# =================================================================
# Total params: 4,964
# Trainable params: 4,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(history.history["val_accuracy"])
# Out:
# [0.5981500148773193, 0.7846250534057617, 0.8176500201225281, 0.8397500514984131, 0.8600250482559204, 0.8740000128746033, 0.8875750303268433, 0.8862000703811646, 0.8993000388145447, 0.8907000422477722, 0.900350034236908, 0.8812750577926636, 0.9040250182151794, 0.9034000635147095, 0.9025250673294067, 0.9108250141143799, 0.899150013923645, 0.8965000510215759]

# %%
plot_history(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Training the model

# %%
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()

# %%
with tf.device('/device:GPU:0'):
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.5, shuffle=True) #validation_data=(X_test, y_test), shuffle=)

# %%
from keras import callbacks
with tf.device('/device:GPU:0'):
    earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                            mode ="min", patience = 2, 
                                            restore_best_weights = True)
    
    history = model.fit(X_train, y_train, batch_size = 32, 
                        epochs = 150, validation_split=0.4,
                        shuffle=True, 
                        callbacks =[earlystopping])
# Out:
# Epoch 1/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0081 - accuracy: 0.3216 - val_loss: 0.0060 - val_accuracy: 0.5982
# Epoch 2/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0050 - accuracy: 0.7054 - val_loss: 0.0041 - val_accuracy: 0.7846
# Epoch 3/150
# 1875/1875 [==============================] - 56s 30ms/step - loss: 0.0036 - accuracy: 0.8018 - val_loss: 0.0033 - val_accuracy: 0.8177
# Epoch 4/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0030 - accuracy: 0.8324 - val_loss: 0.0028 - val_accuracy: 0.8398
# Epoch 5/150
# 1875/1875 [==============================] - 55s 29ms/step - loss: 0.0026 - accuracy: 0.8482 - val_loss: 0.0024 - val_accuracy: 0.8600
# Epoch 6/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0024 - accuracy: 0.8587 - val_loss: 0.0022 - val_accuracy: 0.8740
# Epoch 7/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0022 - accuracy: 0.8688 - val_loss: 0.0020 - val_accuracy: 0.8876
# Epoch 8/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0021 - accuracy: 0.8727 - val_loss: 0.0020 - val_accuracy: 0.8862
# Epoch 9/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0020 - accuracy: 0.8804 - val_loss: 0.0018 - val_accuracy: 0.8993
# Epoch 10/150
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0019 - accuracy: 0.8833 - val_loss: 0.0018 - val_accuracy: 0.8907
# Epoch 11/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0018 - accuracy: 0.8846 - val_loss: 0.0017 - val_accuracy: 0.9004
# Epoch 12/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0018 - accuracy: 0.8884 - val_loss: 0.0018 - val_accuracy: 0.8813
# Epoch 13/150
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0017 - accuracy: 0.8918 - val_loss: 0.0016 - val_accuracy: 0.9040
# Epoch 14/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0017 - accuracy: 0.8933 - val_loss: 0.0016 - val_accuracy: 0.9034
# Epoch 15/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0017 - accuracy: 0.8926 - val_loss: 0.0015 - val_accuracy: 0.9025
# Epoch 16/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0016 - accuracy: 0.8962 - val_loss: 0.0015 - val_accuracy: 0.9108
# Epoch 17/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0016 - accuracy: 0.8997 - val_loss: 0.0015 - val_accuracy: 0.8992
# Epoch 18/150
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0015 - accuracy: 0.8992 - val_loss: 0.0015 - val_accuracy: 0.8965

# %%
def accuracy(model, X_test, y_test):
    # Predicts labels
    y_pred = model.predict(X_test)
    # Finds the coordinate of the value 1 within the predicted label's vector
    y_pred = np.argmax(y_pred, axis=1)
    # Finds the coordinate of the value 1 within the real label's vector
    y_test = np.argmax(y_test, axis=1)
    return np.sum(y_pred == y_test) / len(y_test)

# %%
real_test_gen = itertools.islice(polar_generator(batchsize=1, grid=(10,10)), 20000)

# %%
real_test = list(real_test_gen)
X_real_test = np.array([x for x, y in train])
y_real_test = np.array([array for x, y in train for array in y]) # for label in array])

# %%
print(accuracy(model, X_real_test, y_real_test))
# Out:
# 0.91333

# %%
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_237 (Dense)           (None, 16)                48
#
#  dense_238 (Dense)           (None, 32)                544
#
#  dense_239 (Dense)           (None, 16)                528
#
#  dense_240 (Dense)           (None, 32)                544
#
#  dense_241 (Dense)           (None, 100)               3300
#
# =================================================================
# Total params: 4,964
# Trainable params: 4,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ----------------

# %% [markdown]
# ---------------

# %%
# Functions to see better in order to produce the various sets
X_real_test, y_real_test = zip(*real_test_gen)
X_real_test = np.array(X_real_test)
y_real_test = np.array(y_real_test)

# %%
print(accuracy(model, X_test, y_test))
# Out:
# 0.55868

# %%
for i,el in enumerate(y_pred):
    print(el == y_test_coordinates[i])
    print(el, y_test_coordinates[i])
# Out:
# True
# 50 50
# True
# 26 26
# False
# 46 45
# True
# 3 3
# True
# 26 26
# False
# 38 48
# False
# 29 39
# True
# 4 4
# False
# 14 15
# False
# 46 45
# False
# 38 39
# False
# 79 78
# True
# 91 91
# True
# 44 44
# True
# 99 99
# True
# 87 87
# False
# 1 0
# True
# 31 31
# False
# 23 33
# False
# 87 86
# True
# 71 71
# False
# 50 40
# False
# 26 25
# True
# 54 54
# True
# 37 37
# False
# 75 76
# False
# 96 97
# True
# 67 67
# True
# 8 8
# True
# 96 96
# True
# 9 9
# True
# 8 8
# True
# 71 71
# False
# 38 29
# True
# 22 22
# False
# 7 6
# True
# 18 18
# True
# 75 75
# True
# 50 50
# True
# 90 90
# True
# 32 32
# True
# 58 58
# True
# 84 84
# True
# 15 15
# False
# 8 18
# False
# 9 19
# True
# 43 43
# True
# 42 42
# True
# 38 38
# True
# 74 74
# False
# 99 98
# True
# 22 22
# False
# 29 39
# True
# 10 10
# True
# 96 96
# True
# 1 1
# False
# 96 86
# False
# 79 68
# False
# 26 25
# False
# 87 86
# True
# 20 20
# True
# 84 84
# True
# 20 20
# True
# 43 43
# False
# 79 78
# False
# 67 76
# False
# 64 75
# True
# 2 2
# False
# 18 17
# True
# 19 19
# False
# 75 85
# True
# 96 96
# False
# 56 57
# False
# 44 45
# False
# 93 92
# True
# 9 9
# True
# 47 47
# True
# 52 52
# False
# 38 49
# True
# 16 16
# True
# 14 14
# True
# 22 22
# True
# 26 26
# True
# 21 21
# True
# 34 34
# True
# 11 11
# False
# 96 85
# False
# 79 77
# True
# 71 71
# False
# 26 25
# False
# 91 82
# False
# 79 69
# False
# 79 89
# True
# 96 96
# True
# 20 20
# False
# 12 13
# True
# 9 9
# False
# 84 83
# False
# 84 85
# True
# 54 54
# False
# 27 28
# False
# 99 89
# True
# 53 53
# False
# 55 65
# False
# 0 10
# False
# 71 72
# True
# 29 29
# False
# 79 78
# False
# 59 68
# True
# 31 31
# False
# 12 13
# False
# 56 66
# False
# 99 89
# False
# 96 97
# True
# 32 32
# False
# 10 0
# False
# 21 10
# False
# 75 76
# False
# 51 61
# False
# 96 85
# False
# 67 68
# False
# 23 13
# False
# 70 60
# True
# 53 53
# True
# 21 21
# True
# 8 8
# False
# 79 69
# True
# 22 22
# False
# 5 6
# True
# 44 44
# True
# 63 63
# True
# 84 84
# False
# 29 39
# True
# 10 10
# True
# 63 63
# True
# 71 71
# True
# 35 35
# False
# 73 72
# True
# 42 42
# True
# 64 64
# False
# 54 53
# True
# 90 90
# True
# 93 93
# True
# 94 94
# True
# 34 34
# False
# 84 83
# True
# 26 26
# True
# 73 73
# True
# 38 38
# True
# 33 33
# True
# 34 34
# True
# 96 96
# False
# 47 58
# True
# 7 7
# True
# 82 82
# True
# 54 54
# True
# 12 12
# True
# 93 93
# True
# 50 50
# True
# 55 55
# True
# 7 7
# True
# 25 25
# True
# 20 20
# False
# 59 49
# True
# 1 1
# True
# 67 67
# True
# 58 58
# False
# 22 33
# True
# 90 90
# False
# 79 78
# False
# 96 97
# False
# 96 97
# True
# 80 80
# True
# 31 31
# False
# 74 85
# False
# 38 49
# True
# 9 9
# True
# 93 93
# False
# 84 85
# False
# 26 25
# True
# 19 19
# True
# 96 96
# False
# 96 97
# True
# 22 22
# True
# 23 23
# True
# 18 18
# False
# 71 82
# False
# 47 57
# True
# 51 51
# True
# 20 20
# True
# 87 87
# False
# 87 77
# False
# 26 27
# False
# 79 88
# True
# 67 67
# True
# 87 87
# True
# 54 54
# True
# 55 55
# True
# 41 41
# True
# 21 21
# True
# 23 23
# False
# 26 17
# False
# 67 66
# True
# 24 24
# True
# 4 4
# False
# 8 17
# True
# 84 84
# False
# 34 24
# False
# 26 25
# True
# 61 61
# False
# 64 66
# False
# 99 87
# False
# 79 89
# True
# 4 4
# False
# 71 72
# True
# 73 73
# True
# 10 10
# True
# 94 94
# True
# 94 94
# True
# 21 21
# False
# 67 66
# True
# 19 19
# True
# 93 93
# True
# 60 60
# False
# 56 57
# False
# 38 28
# True
# 42 42
# False
# 84 83
# False
# 54 55
# True
# 67 67
# True
# 53 53
# True
# 60 60
# False
# 8 9
# False
# 35 44
# False
# 15 16
# True
# 37 37
# False
# 38 28
# True
# 87 87
# False
# 87 86
# False
# 35 45
# False
# 67 68
# False
# 27 36
# True
# 82 82
# True
# 35 35
# True
# 7 7
# False
# 35 36
# False
# 99 98
# True
# 5 5
# False
# 15 16
# True
# 64 64
# False
# 93 92
# False
# 35 36
# True
# 59 59
# True
# 99 99
# True
# 23 23
# False
# 35 34
# True
# 7 7
# False
# 99 88
# True
# 5 5
# True
# 62 62
# True
# 75 75
# False
# 44 45
# True
# 29 29
# True
# 70 70
# False
# 8 17
# True
# 40 40
# False
# 96 95
# False
# 38 28
# False
# 64 75
# True
# 37 37
# True
# 84 84
# False
# 99 89
# True
# 34 34
# False
# 55 66
# False
# 54 55
# True
# 52 52
# False
# 79 89
# False
# 79 68
# False
# 14 24
# False
# 84 83
# True
# 32 32
# False
# 44 45
# True
# 67 67
# False
# 84 82
# True
# 96 96
# False
# 5 6
# False
# 14 13
# False
# 90 80
# True
# 6 6
# False
# 71 72
# True
# 4 4
# True
# 12 12
# False
# 12 13
# True
# 55 55
# False
# 29 39
# True
# 94 94
# True
# 63 63
# True
# 15 15
# False
# 87 88
# False
# 51 61
# False
# 0 1
# True
# 42 42
# False
# 67 68
# True
# 42 42
# True
# 59 59
# True
# 64 64
# False
# 38 49
# False
# 91 82
# True
# 94 94
# False
# 71 72
# True
# 75 75
# True
# 60 60
# True
# 31 31
# True
# 3 3
# True
# 99 99
# False
# 2 3
# False
# 8 17
# False
# 44 45
# False
# 91 81
# True
# 43 43
# True
# 34 34
# False
# 74 85
# True
# 29 29
# True
# 47 47
# False
# 96 95
# False
# 52 62
# True
# 61 61
# True
# 26 26
# False
# 10 0
# False
# 64 65
# True
# 71 71
# True
# 1 1
# False
# 8 9
# False
# 38 29
# False
# 38 49
# False
# 73 72
# False
# 44 45
# False
# 5 6
# True
# 9 9
# True
# 94 94
# True
# 21 21
# True
# 31 31
# True
# 99 99
# True
# 27 27
# True
# 21 21
# False
# 55 56
# False
# 67 66
# True
# 67 67
# True
# 0 0
# False
# 84 73
# True
# 22 22
# False
# 99 98
# False
# 56 57
# True
# 27 27
# True
# 67 67
# True
# 15 15
# False
# 44 54
# True
# 20 20
# False
# 79 69
# True
# 5 5
# True
# 24 24
# True
# 1 1
# True
# 22 22
# True
# 30 30
# True
# 0 0
# True
# 61 61
# True
# 3 3
# True
# 64 64
# True
# 42 42
# False
# 27 36
# False
# 23 33
# False
# 64 65
# False
# 56 57
# False
# 71 72
# True
# 87 87
# False
# 79 69
# True
# 2 2
# True
# 96 96
# False
# 96 86
# True
# 22 22
# True
# 34 34
# True
# 60 60
# False
# 38 39
# False
# 64 63
# True
# 32 32
# True
# 87 87
# True
# 32 32
# True
# 44 44
# True
# 64 64
# True
# 10 10
# False
# 96 97
# True
# 62 62
# True
# 1 1
# True
# 62 62
# False
# 67 68
# False
# 14 15
# False
# 27 28
# True
# 55 55
# False
# 84 85
# False
# 23 24
# False
# 87 88
# True
# 27 27
# False
# 96 97
# True
# 93 93
# True
# 19 19
# False
# 96 85
# True
# 26 26
# False
# 75 76
# False
# 87 77
# False
# 96 95
# True
# 15 15
# True
# 11 11
# False
# 1 2
# True
# 11 11
# True
# 58 58
# False
# 1 0
# False
# 0 10
# False
# 93 92
# True
# 29 29
# False
# 3 2
# False
# 91 81
# False
# 99 98
# True
# 22 22
# False
# 54 53
# False
# 67 77
# True
# 10 10
# False
# 23 24
# True
# 25 25
# False
# 44 45
# True
# 34 34
# True
# 22 22
# True
# 4 4
# True
# 58 58
# False
# 96 86
# True
# 70 70
# True
# 67 67
# True
# 25 25
# False
# 96 98
# False
# 96 86
# False
# 9 19
# False
# 79 88
# True
# 32 32
# True
# 84 84
# False
# 84 94
# True
# 73 73
# False
# 64 65
# False
# 64 75
# False
# 55 56
# True
# 93 93
# False
# 67 77
# True
# 59 59
# False
# 38 39
# True
# 31 31
# False
# 84 83
# True
# 19 19
# False
# 51 61
# True
# 24 24
# True
# 93 93
# True
# 43 43
# False
# 15 16
# True
# 64 64
# False
# 3 13
# False
# 75 76
# True
# 19 19
# True
# 96 96
# True
# 64 64
# True
# 56 56
# True
# 30 30
# True
# 26 26
# True
# 4 4
# True
# 41 41
# True
# 21 21
# False
# 64 66
# True
# 71 71
# False
# 29 39
# False
# 44 45
# False
# 8 17
# False
# 32 33
# True
# 9 9
# False
# 44 45
# True
# 50 50
# True
# 59 59
# True
# 0 0
# True
# 71 71
# False
# 47 58
# True
# 23 23
# True
# 7 7
# True
# 96 96
# False
# 71 61
# True
# 51 51
# True
# 26 26
# False
# 10 0
# False
# 96 97
# False
# 9 19
# False
# 80 71
# False
# 47 46
# False
# 0 10
# True
# 20 20
# True
# 44 44
# False
# 99 88
# False
# 29 49
# True
# 19 19
# True
# 42 42
# False
# 99 89
# False
# 91 92
# True
# 43 43
# False
# 29 39
# False
# 25 24
# True
# 38 38
# True
# 26 26
# True
# 94 94
# True
# 71 71
# True
# 94 94
# False
# 10 0
# True
# 14 14
# False
# 87 77
# True
# 2 2
# False
# 96 98
# False
# 99 98
# True
# 8 8
# True
# 91 91
# True
# 18 18
# True
# 74 74
# False
# 55 65
# True
# 38 38
# False
# 79 69
# True
# 64 64
# False
# 54 53
# True
# 52 52
# False
# 79 78
# True
# 64 64
# False
# 84 74
# True
# 15 15
# True
# 6 6
# False
# 96 85
# False
# 79 77
# False
# 64 65
# False
# 27 28
# True
# 3 3
# False
# 29 19
# False
# 64 53
# True
# 93 93
# True
# 34 34
# False
# 50 40
# False
# 91 92
# True
# 9 9
# True
# 41 41
# False
# 23 24
# True
# 74 74
# True
# 82 82
# True
# 41 41
# True
# 35 35
# True
# 8 8
# True
# 19 19
# True
# 29 29
# True
# 6 6
# True
# 75 75
# False
# 38 49
# False
# 29 49
# True
# 35 35
# False
# 10 20
# False
# 41 42
# False
# 47 57
# True
# 53 53
# True
# 16 16
# False
# 29 39
# True
# 6 6
# True
# 47 47
# False
# 29 39
# True
# 12 12
# True
# 43 43
# True
# 52 52
# True
# 2 2
# True
# 23 23
# True
# 84 84
# False
# 35 45
# False
# 47 46
# False
# 59 69
# True
# 40 40
# False
# 73 63
# False
# 7 6
# True
# 6 6
# True
# 27 27
# True
# 3 3
# False
# 84 82
# False
# 71 60
# True
# 60 60
# False
# 27 28
# True
# 31 31
# True
# 1 1
# True
# 18 18
# True
# 22 22
# True
# 40 40
# True
# 22 22
# True
# 15 15
# True
# 67 67
# True
# 71 71
# False
# 8 17
# True
# 73 73
# False
# 84 72
# True
# 41 41
# False
# 38 49
# True
# 71 71
# True
# 29 29
# True
# 31 31
# True
# 58 58
# False
# 99 88
# False
# 79 78
# False
# 2 1
# False
# 73 72
# True
# 63 63
# True
# 7 7
# False
# 30 31
# True
# 38 38
# True
# 0 0
# False
# 64 65
# False
# 10 0
# True
# 16 16
# False
# 71 72
# False
# 79 78
# False
# 91 81
# False
# 99 98
# False
# 71 61
# False
# 19 29
# True
# 31 31
# True
# 1 1
# False
# 71 61
# True
# 22 22
# False
# 56 57
# True
# 41 41
# True
# 74 74
# True
# 14 14
# True
# 35 35
# False
# 4 5
# True
# 71 71
# True
# 20 20
# True
# 52 52
# False
# 60 70
# False
# 71 61
# True
# 74 74
# False
# 64 74
# True
# 90 90
# True
# 26 26
# True
# 7 7
# False
# 55 56
# True
# 87 87
# True
# 41 41
# True
# 79 79
# False
# 96 86
# True
# 52 52
# True
# 29 29
# False
# 26 16
# True
# 90 90
# True
# 1 1
# True
# 33 33
# False
# 27 36
# True
# 33 33
# False
# 96 97
# True
# 33 33
# True
# 2 2
# True
# 50 50
# False
# 73 72
# True
# 29 29
# True
# 58 58
# False
# 60 70
# True
# 8 8
# True
# 1 1
# True
# 91 91
# True
# 34 34
# True
# 72 72
# False
# 67 68
# True
# 79 79
# False
# 52 63
# False
# 27 28
# True
# 79 79
# True
# 55 55
# False
# 62 72
# False
# 50 40
# False
# 79 69
# True
# 33 33
# True
# 27 27
# False
# 99 87
# False
# 26 17
# False
# 99 88
# False
# 14 15
# True
# 34 34
# False
# 96 97
# True
# 90 90
# True
# 41 41
# False
# 41 51
# True
# 3 3
# False
# 96 97
# False
# 84 94
# False
# 87 86
# False
# 47 57
# True
# 14 14
# False
# 38 47
# True
# 22 22
# True
# 23 23
# False
# 84 83
# True
# 38 38
# False
# 91 92
# True
# 10 10
# False
# 67 76
# True
# 52 52
# False
# 79 78
# True
# 67 67
# False
# 23 24
# False
# 40 30
# True
# 3 3
# True
# 3 3
# True
# 9 9
# True
# 14 14
# True
# 21 21
# False
# 59 49
# True
# 43 43
# True
# 9 9
# False
# 38 48
# False
# 27 36
# False
# 35 45
# True
# 18 18
# False
# 38 28
# False
# 35 36
# True
# 52 52
# True
# 31 31
# False
# 67 68
# True
# 19 19
# True
# 99 99
# False
# 38 47
# True
# 70 70
# False
# 94 93
# False
# 79 78
# False
# 41 51
# True
# 2 2
# True
# 53 53
# True
# 34 34
# False
# 56 66
# True
# 51 51
# True
# 10 10
# True
# 0 0
# True
# 60 60
# False
# 79 89
# False
# 9 19
# False
# 59 68
# True
# 80 80
# False
# 8 17
# False
# 38 48
# True
# 9 9
# False
# 99 98
# True
# 20 20
# False
# 38 39
# False
# 99 89
# True
# 15 15
# True
# 27 27
# False
# 37 46
# True
# 80 80
# True
# 5 5
# True
# 11 11
# True
# 41 41
# True
# 60 60
# False
# 38 48
# False
# 91 92
# True
# 67 67
# False
# 91 82
# False
# 26 16
# True
# 30 30
# True
# 41 41
# True
# 5 5
# False
# 91 92
# False
# 31 32
# False
# 64 65
# False
# 22 23
# True
# 55 55
# False
# 27 28
# False
# 67 66
# False
# 96 85
# True
# 93 93
# False
# 79 88
# True
# 2 2
# True
# 30 30
# True
# 35 35
# True
# 84 84
# False
# 67 68
# True
# 34 34
# True
# 52 52
# False
# 99 88
# False
# 37 47
# True
# 55 55
# True
# 33 33
# False
# 99 89
# True
# 79 79
# True
# 52 52
# False
# 24 25
# True
# 52 52
# False
# 37 28
# True
# 55 55
# False
# 79 69
# True
# 7 7
# True
# 75 75
# False
# 74 85
# False
# 84 85
# False
# 91 92
# False
# 7 17
# False
# 60 70
# False
# 67 68
# False
# 79 69
# False
# 96 97
# True
# 73 73
# True
# 11 11
# False
# 2 3
# False
# 23 24
# False
# 5 6
# True
# 56 56
# True
# 93 93
# True
# 99 99
# False
# 26 27
# False
# 43 44
# False
# 20 21
# True
# 41 41
# False
# 94 93
# False
# 87 77
# False
# 96 85
# False
# 96 86
# True
# 37 37
# True
# 20 20
# True
# 70 70
# True
# 91 91
# False
# 87 86
# False
# 96 98
# False
# 38 48
# False
# 38 28
# False
# 27 28
# False
# 44 45
# True
# 47 47
# False
# 84 83
# False
# 79 78
# False
# 79 78
# False
# 84 83
# True
# 26 26
# True
# 63 63
# False
# 79 69
# True
# 30 30
# False
# 79 88
# False
# 59 49
# False
# 84 73
# True
# 99 99
# True
# 8 8
# True
# 67 67
# False
# 99 88
# False
# 84 83
# False
# 91 81
# False
# 96 98
# True
# 41 41
# False
# 90 81
# True
# 93 93
# True
# 3 3
# True
# 93 93
# False
# 55 65
# True
# 90 90
# True
# 32 32
# True
# 54 54
# True
# 55 55
# False
# 29 39
# False
# 64 65
# False
# 7 17
# True
# 96 96
# False
# 64 75
# False
# 8 17
# True
# 82 82
# True
# 42 42
# True
# 59 59
# False
# 47 57
# True
# 94 94
# False
# 32 33
# True
# 38 38
# True
# 10 10
# True
# 67 67
# False
# 91 81
# False
# 84 83
# False
# 23 24
# False
# 55 66
# False
# 38 48
# False
# 79 69
# False
# 64 65
# False
# 29 39
# True
# 43 43
# True
# 5 5
# False
# 38 29
# True
# 90 90
# False
# 27 28
# False
# 84 94
# False
# 59 49
# True
# 72 72
# False
# 99 98
# False
# 29 39
# True
# 8 8
# False
# 43 44
# True
# 3 3
# False
# 1 2
# False
# 9 19
# True
# 84 84
# True
# 59 59
# True
# 54 54
# True
# 43 43
# False
# 5 6
# False
# 26 16
# True
# 71 71
# False
# 38 49
# True
# 19 19
# True
# 7 7
# False
# 56 66
# True
# 67 67
# True
# 61 61
# True
# 23 23
# True
# 7 7
# True
# 87 87
# True
# 43 43
# False
# 55 56
# True
# 94 94
# True
# 50 50
# False
# 84 83
# False
# 27 28
# False
# 20 30
# False
# 91 92
# True
# 23 23
# False
# 21 22
# False
# 96 97
# False
# 62 63
# False
# 51 61
# False
# 29 39
# False
# 55 56
# True
# 90 90
# True
# 29 29
# True
# 84 84
# True
# 91 91
# False
# 90 80
# True
# 8 8
# True
# 71 71
# True
# 34 34
# True
# 19 19
# True
# 79 79
# False
# 67 66
# True
# 25 25
# True
# 67 67
# True
# 34 34
# True
# 74 74
# False
# 20 30
# True
# 90 90
# True
# 54 54
# False
# 79 69
# True
# 20 20
# False
# 67 76
# True
# 62 62
# True
# 87 87
# False
# 5 6
# False
# 91 92
# False
# 71 82
# False
# 1 0
# False
# 70 80
# False
# 64 65
# True
# 60 60
# True
# 15 15
# False
# 91 82
# True
# 43 43
# True
# 99 99
# True
# 42 42
# False
# 38 49
# False
# 10 0
# True
# 5 5
# True
# 8 8
# False
# 91 81
# False
# 84 83
# False
# 96 86
# True
# 59 59
# True
# 37 37
# False
# 99 87
# True
# 37 37
# True
# 23 23
# True
# 25 25
# True
# 34 34
# True
# 71 71
# True
# 44 44
# True
# 53 53
# True
# 74 74
# True
# 75 75
# True
# 54 54
# True
# 6 6
# True
# 15 15
# True
# 22 22
# False
# 38 37
# True
# 5 5
# True
# 93 93
# True
# 29 29
# False
# 96 86
# True
# 61 61
# True
# 67 67
# True
# 99 99
# False
# 56 67
# True
# 14 14
# True
# 21 21
# True
# 96 96
# True
# 64 64
# False
# 75 76
# True
# 50 50
# True
# 41 41
# False
# 91 92
# True
# 41 41
# True
# 20 20
# True
# 2 2
# True
# 55 55
# True
# 22 22
# True
# 67 67
# True
# 10 10
# True
# 84 84
# True
# 96 96
# False
# 38 39
# True
# 44 44
# True
# 63 63
# False
# 35 45
# False
# 84 93
# False
# 79 69
# True
# 31 31
# True
# 22 22
# True
# 8 8
# False
# 84 83
# False
# 44 45
# False
# 4 5
# False
# 38 49
# True
# 75 75
# True
# 52 52
# False
# 47 46
# False
# 84 93
# False
# 91 81
# False
# 67 68
# True
# 41 41
# True
# 91 91
# True
# 19 19
# False
# 56 57
# False
# 38 49
# True
# 60 60
# True
# 24 24
# False
# 38 28
# True
# 52 52
# False
# 22 23
# False
# 84 83
# False
# 79 69
# False
# 99 98
# False
# 38 49
# True
# 64 64
# True
# 27 27
# False
# 75 76
# False
# 64 65
# True
# 37 37
# True
# 67 67
# False
# 79 69
# False
# 96 95
# True
# 6 6
# False
# 38 29
# True
# 71 71
# True
# 62 62
# True
# 1 1
# True
# 67 67
# True
# 55 55
# True
# 51 51
# True
# 46 46
# True
# 84 84
# False
# 37 46
# False
# 7 17
# True
# 34 34
# False
# 96 97
# False
# 37 36
# False
# 60 70
# True
# 18 18
# False
# 23 24
# False
# 26 25
# True
# 70 70
# False
# 38 48
# False
# 2 1
# True
# 5 5
# True
# 37 37
# True
# 62 62
# True
# 15 15
# False
# 44 45
# False
# 44 45
# False
# 27 28
# False
# 18 19
# True
# 24 24
# False
# 84 83
# True
# 11 11
# True
# 4 4
# False
# 99 98
# False
# 34 44
# False
# 79 78
# False
# 37 36
# False
# 55 46
# False
# 27 37
# True
# 90 90
# False
# 47 46
# True
# 91 91
# True
# 64 64
# True
# 56 56
# False
# 23 24
# False
# 8 17
# False
# 60 70
# True
# 38 38
# True
# 56 56
# True
# 33 33
# True
# 54 54
# True
# 23 23
# True
# 67 67
# True
# 80 80
# False
# 64 63
# False
# 59 49
# True
# 6 6
# False
# 38 39
# True
# 50 50
# False
# 38 37
# False
# 19 29
# True
# 2 2
# True
# 61 61
# True
# 59 59
# False
# 84 85
# False
# 47 57
# True
# 40 40
# True
# 30 30
# False
# 23 24
# True
# 70 70
# False
# 50 60
# True
# 3 3
# True
# 56 56
# False
# 91 81
# False
# 37 36
# True
# 31 31
# True
# 22 22
# False
# 73 72
# False
# 64 63
# True
# 75 75
# True
# 33 33
# False
# 79 89
# True
# 22 22
# False
# 26 27
# True
# 2 2
# False
# 91 92
# True
# 51 51
# True
# 18 18
# True
# 12 12
# False
# 67 68
# True
# 54 54
# True
# 42 42
# True
# 67 67
# True
# 43 43
# True
# 10 10
# False
# 99 89
# True
# 84 84
# True
# 99 99
# True
# 41 41
# False
# 52 53
# False
# 91 81
# False
# 59 58
# True
# 44 44
# True
# 59 59
# True
# 59 59
# True
# 41 41
# False
# 1 2
# True
# 62 62
# False
# 18 17
# False
# 15 16
# False
# 79 89
# False
# 18 17
# False
# 79 78
# True
# 6 6
# False
# 79 69
# False
# 10 0
# True
# 91 91
# False
# 4 5
# True
# 43 43
# False
# 87 77
# True
# 3 3
# True
# 6 6
# False
# 56 57
# True
# 93 93
# True
# 58 58
# False
# 71 72
# True
# 71 71
# True
# 54 54
# False
# 9 19
# False
# 93 92
# True
# 26 26
# True
# 41 41
# True
# 82 82
# False
# 79 69
# False
# 40 30
# True
# 71 71
# True
# 80 80
# False
# 79 68
# False
# 47 46
# True
# 10 10
# False
# 50 40
# True
# 8 8
# False
# 99 89
# True
# 67 67
# True
# 36 36
# True
# 87 87
# False
# 64 65
# True
# 4 4
# False
# 84 85
# False
# 84 85
# True
# 32 32
# False
# 67 66
# False
# 96 86
# True
# 32 32
# False
# 27 28
# True
# 50 50
# True
# 91 91
# True
# 21 21
# True
# 44 44
# True
# 38 38
# False
# 0 1
# True
# 96 96
# False
# 93 92
# False
# 35 45
# False
# 18 19
# False
# 22 33
# True
# 16 16
# True
# 90 90
# False
# 64 54
# True
# 82 82
# False
# 91 81
# True
# 99 99
# True
# 70 70
# True
# 43 43
# False
# 38 48
# False
# 91 92
# True
# 8 8
# True
# 29 29
# False
# 32 33
# False
# 67 66
# True
# 70 70
# True
# 67 67
# True
# 25 25
# False
# 96 95
# False
# 87 86
# True
# 23 23
# False
# 27 28
# True
# 80 80
# True
# 18 18
# True
# 46 46
# True
# 0 0
# True
# 31 31
# True
# 52 52
# True
# 40 40
# False
# 74 75
# True
# 84 84
# True
# 4 4
# False
# 37 28
# True
# 60 60
# False
# 96 86
# False
# 2 1
# False
# 71 82
# True
# 3 3
# False
# 96 97
# True
# 64 64
# True
# 75 75
# True
# 21 21
# True
# 79 79
# False
# 21 31
# True
# 42 42
# True
# 70 70
# True
# 75 75
# False
# 55 56
# False
# 50 60
# False
# 79 77
# True
# 9 9
# False
# 87 77
# True
# 33 33
# True
# 32 32
# False
# 96 97
# False
# 96 98
# False
# 4 5
# True
# 82 82
# True
# 63 63
# True
# 99 99
# True
# 2 2
# True
# 32 32
# True
# 14 14
# False
# 51 61
# True
# 64 64
# True
# 37 37
# True
# 75 75
# False
# 38 39
# True
# 9 9
# False
# 12 13
# False
# 42 52
# True
# 35 35
# True
# 37 37
# True
# 0 0
# True
# 93 93
# True
# 84 84
# False
# 59 49
# True
# 99 99
# False
# 64 65
# True
# 14 14
# True
# 51 51
# False
# 91 81
# True
# 18 18
# True
# 26 26
# True
# 7 7
# False
# 50 60
# True
# 8 8
# False
# 87 77
# True
# 43 43
# True
# 32 32
# False
# 79 69
# True
# 16 16
# False
# 84 85
# True
# 5 5
# True
# 33 33
# False
# 44 45
# False
# 64 74
# False
# 27 28
# True
# 91 91
# True
# 79 79
# True
# 37 37
# True
# 32 32
# False
# 26 17
# True
# 47 47
# False
# 84 73
# False
# 12 2
# True
# 13 13
# False
# 93 92
# False
# 29 49
# False
# 75 76
# True
# 3 3
# False
# 5 6
# True
# 25 25
# True
# 47 47
# False
# 79 78
# True
# 63 63
# False
# 64 63
# True
# 59 59
# True
# 47 47
# True
# 41 41
# True
# 8 8
# False
# 96 85
# True
# 84 84
# True
# 40 40
# True
# 51 51
# False
# 87 86
# False
# 96 95
# True
# 1 1
# True
# 37 37
# False
# 11 10
# True
# 20 20
# False
# 87 86
# False
# 44 45
# True
# 0 0
# False
# 75 77
# True
# 11 11
# False
# 64 63
# True
# 87 87
# True
# 8 8
# True
# 7 7
# False
# 4 5
# True
# 71 71
# True
# 8 8
# False
# 59 49
# True
# 64 64
# True
# 67 67
# True
# 2 2
# True
# 93 93
# True
# 43 43
# False
# 38 48
# True
# 6 6
# True
# 71 71
# True
# 55 55
# True
# 5 5
# True
# 31 31
# False
# 79 68
# False
# 80 70
# True
# 23 23
# True
# 27 27
# True
# 8 8
# True
# 8 8
# True
# 74 74
# False
# 64 63
# False
# 91 92
# False
# 18 17
# False
# 37 46
# False
# 91 92
# False
# 8 9
# True
# 54 54
# False
# 99 89
# True
# 14 14
# True
# 51 51
# False
# 99 89
# False
# 84 73
# True
# 21 21
# False
# 26 17
# False
# 7 17
# False
# 73 72
# False
# 99 98
# True
# 10 10
# False
# 93 92
# True
# 35 35
# True
# 21 21
# False
# 32 42
# True
# 70 70
# True
# 54 54
# True
# 80 80
# True
# 7 7
# True
# 62 62
# True
# 4 4
# False
# 64 66
# False
# 84 85
# True
# 18 18
# True
# 20 20
# True
# 79 79
# True
# 4 4
# True
# 55 55
# True
# 8 8
# False
# 75 76
# True
# 59 59
# True
# 27 27
# True
# 3 3
# True
# 34 34
# True
# 94 94
# False
# 79 68
# False
# 79 77
# False
# 29 39
# False
# 38 39
# False
# 60 70
# True
# 4 4
# False
# 12 13
# True
# 22 22
# True
# 59 59
# False
# 90 81
# False
# 51 41
# False
# 29 49
# True
# 8 8
# True
# 53 53
# False
# 38 28
# True
# 24 24
# False
# 84 83
# False
# 55 56
# False
# 43 44
# False
# 43 44
# False
# 91 92
# False
# 0 1
# False
# 38 48
# True
# 72 72
# True
# 22 22
# False
# 96 94
# False
# 56 57
# True
# 15 15
# True
# 5 5
# False
# 99 89
# False
# 22 32
# True
# 91 91
# False
# 38 49
# True
# 0 0
# True
# 46 46
# False
# 23 33
# False
# 71 72
# True
# 45 45
# False
# 80 70
# False
# 15 16
# False
# 74 75
# True
# 4 4
# False
# 67 66
# False
# 84 73
# True
# 26 26
# True
# 40 40
# True
# 15 15
# False
# 19 28
# True
# 64 64
# True
# 16 16
# True
# 15 15
# True
# 61 61
# True
# 51 51
# True
# 15 15
# False
# 79 68
# False
# 38 39
# True
# 99 99
# False
# 79 69
# True
# 30 30
# True
# 12 12
# False
# 91 92
# True
# 50 50
# False
# 75 76
# True
# 42 42
# True
# 31 31
# True
# 3 3
# True
# 51 51
# False
# 27 17
# True
# 40 40
# False
# 71 72
# False
# 59 49
# False
# 84 94
# False
# 96 95
# False
# 47 58
# False
# 96 97
# False
# 42 43
# True
# 75 75
# False
# 96 97
# True
# 91 91
# False
# 29 49
# True
# 93 93
# True
# 99 99
# True
# 18 18
# False
# 8 9
# False
# 79 78
# True
# 53 53
# True
# 44 44
# True
# 27 27
# True
# 60 60
# True
# 84 84
# True
# 90 90
# False
# 96 86
# False
# 96 97
# False
# 71 72
# False
# 42 32
# False
# 96 85
# True
# 0 0
# True
# 93 93
# True
# 15 15
# True
# 3 3
# True
# 33 33
# False
# 10 0
# True
# 25 25
# True
# 63 63
# True
# 94 94
# True
# 13 13
# True
# 10 10
# False
# 71 81
# True
# 2 2
# False
# 90 81
# False
# 38 48
# False
# 64 65
# True
# 93 93
# True
# 91 91
# True
# 38 38
# True
# 47 47
# False
# 55 45
# True
# 8 8
# True
# 4 4
# False
# 91 81
# False
# 84 83
# True
# 67 67
# True
# 3 3
# True
# 62 62
# True
# 44 44
# False
# 55 56
# True
# 84 84
# True
# 44 44
# True
# 32 32
# True
# 52 52
# False
# 26 16
# False
# 37 46
# False
# 96 97
# False
# 84 83
# True
# 9 9
# True
# 35 35
# False
# 51 61
# False
# 50 40
# True
# 61 61
# True
# 67 67
# True
# 20 20
# True
# 63 63
# True
# 79 79
# True
# 31 31
# False
# 96 98
# True
# 13 13
# False
# 64 75
# False
# 96 97
# True
# 52 52
# False
# 96 97
# True
# 29 29
# True
# 59 59
# True
# 24 24
# False
# 84 83
# False
# 50 40
# True
# 20 20
# True
# 91 91
# True
# 74 74
# True
# 19 19
# False
# 67 66
# True
# 37 37
# False
# 26 16
# True
# 99 99
# True
# 51 51
# False
# 67 68
# False
# 35 46
# False
# 67 66
# True
# 75 75
# False
# 64 65
# False
# 15 16
# True
# 93 93
# True
# 70 70
# False
# 71 82
# True
# 91 91
# True
# 6 6
# False
# 80 70
# True
# 2 2
# False
# 56 57
# False
# 12 13
# True
# 24 24
# False
# 43 44
# True
# 90 90
# True
# 7 7
# False
# 79 77
# True
# 18 18
# True
# 70 70
# True
# 71 71
# True
# 58 58
# True
# 79 79
# True
# 59 59
# True
# 53 53
# False
# 38 47
# True
# 16 16
# False
# 64 65
# False
# 50 60
# True
# 8 8
# False
# 96 97
# True
# 20 20
# False
# 99 98
# False
# 79 68
# False
# 59 69
# False
# 96 97
# False
# 96 97
# True
# 90 90
# False
# 75 85
# False
# 29 39
# False
# 75 76
# True
# 54 54
# False
# 55 56
# False
# 41 31
# False
# 71 61
# True
# 96 96
# True
# 30 30
# False
# 67 76
# False
# 8 9
# True
# 61 61
# False
# 84 83
# False
# 50 40
# True
# 12 12
# False
# 18 28
# True
# 84 84
# False
# 99 89
# True
# 67 67
# True
# 32 32
# False
# 71 82
# True
# 55 55
# False
# 64 65
# True
# 1 1
# False
# 1 0
# False
# 56 57
# True
# 25 25
# True
# 90 90
# True
# 42 42
# True
# 62 62
# False
# 0 10
# False
# 64 65
# True
# 29 29
# False
# 12 13
# True
# 87 87
# False
# 79 77
# False
# 54 53
# False
# 71 82
# False
# 87 86
# True
# 60 60
# True
# 91 91
# True
# 90 90
# True
# 43 43
# False
# 54 53
# False
# 0 10
# False
# 38 37
# True
# 0 0
# True
# 31 31
# True
# 23 23
# True
# 7 7
# True
# 8 8
# False
# 64 65
# False
# 1 0
# True
# 40 40
# True
# 20 20
# False
# 55 46
# False
# 1 0
# True
# 24 24
# False
# 87 77
# True
# 55 55
# False
# 8 17
# False
# 35 45
# True
# 36 36
# False
# 91 81
# True
# 50 50
# True
# 99 99
# True
# 84 84
# True
# 7 7
# False
# 41 42
# True
# 30 30
# True
# 75 75
# True
# 64 64
# True
# 35 35
# False
# 96 94
# False
# 70 80
# True
# 23 23
# True
# 67 67
# True
# 94 94
# True
# 63 63
# True
# 82 82
# True
# 19 19
# True
# 23 23
# False
# 79 68
# True
# 51 51
# True
# 91 91
# False
# 93 92
# True
# 74 74
# True
# 60 60
# False
# 91 82
# False
# 56 57
# False
# 38 37
# False
# 26 17
# False
# 37 46
# False
# 91 81
# False
# 38 29
# False
# 55 56
# False
# 84 83
# False
# 38 37
# True
# 94 94
# False
# 99 98
# False
# 0 11
# True
# 7 7
# False
# 26 16
# True
# 9 9
# True
# 9 9
# True
# 75 75
# False
# 96 97
# True
# 59 59
# False
# 79 78
# False
# 96 95
# True
# 53 53
# False
# 22 13
# True
# 11 11
# True
# 67 67
# False
# 23 13
# True
# 18 18
# False
# 99 98
# False
# 62 72
# True
# 2 2
# False
# 96 87
# False
# 71 72
# False
# 96 85
# True
# 11 11
# True
# 37 37
# True
# 26 26
# False
# 87 86
# True
# 6 6
# False
# 35 45
# True
# 96 96
# True
# 94 94
# False
# 9 19
# True
# 99 99
# False
# 96 85
# True
# 90 90
# True
# 29 29
# False
# 79 68
# False
# 27 36
# True
# 96 96
# True
# 96 96
# True
# 3 3
# False
# 75 76
# False
# 23 13
# False
# 37 46
# False
# 79 89
# True
# 18 18
# True
# 58 58
# True
# 59 59
# True
# 70 70
# False
# 15 16
# False
# 79 69
# True
# 38 38
# True
# 8 8
# True
# 59 59
# True
# 60 60
# True
# 50 50
# True
# 75 75
# True
# 38 38
# True
# 25 25
# False
# 19 9
# False
# 55 56
# True
# 54 54
# True
# 22 22
# False
# 74 73
# True
# 64 64
# True
# 94 94
# True
# 31 31
# True
# 15 15
# False
# 29 39
# True
# 15 15
# True
# 75 75
# False
# 9 19
# True
# 4 4
# True
# 54 54
# False
# 91 92
# True
# 54 54
# False
# 96 94
# True
# 22 22
# True
# 84 84
# True
# 44 44
# True
# 32 32
# True
# 37 37
# True
# 43 43
# True
# 74 74
# True
# 96 96
# True
# 36 36
# True
# 73 73
# False
# 79 88
# True
# 20 20
# True
# 9 9
# False
# 26 27
# True
# 16 16
# True
# 11 11
# False
# 91 82
# False
# 79 69
# True
# 5 5
# True
# 93 93
# True
# 15 15
# False
# 96 97
# False
# 8 17
# False
# 38 48
# True
# 25 25
# True
# 2 2
# True
# 29 29
# True
# 8 8
# False
# 55 56
# False
# 96 97
# True
# 7 7
# True
# 42 42
# False
# 52 62
# True
# 31 31
# False
# 96 87
# False
# 75 76
# True
# 52 52
# True
# 9 9
# True
# 27 27
# True
# 50 50
# True
# 50 50
# True
# 93 93
# False
# 96 86
# False
# 60 70
# False
# 96 85
# True
# 63 63
# True
# 19 19
# False
# 26 16
# False
# 99 89
# False
# 30 40
# True
# 20 20
# True
# 21 21
# False
# 79 77
# False
# 64 65
# False
# 38 47
# True
# 26 26
# True
# 22 22
# True
# 84 84
# False
# 79 78
# False
# 71 72
# True
# 59 59
# True
# 35 35
# False
# 23 14
# True
# 38 38
# True
# 55 55
# True
# 7 7
# True
# 25 25
# False
# 96 98
# False
# 55 56
# True
# 99 99
# False
# 38 48
# True
# 96 96
# False
# 1 0
# True
# 37 37
# False
# 64 65
# False
# 64 65
# True
# 93 93
# True
# 84 84
# False
# 79 89
# True
# 20 20
# True
# 8 8
# False
# 82 72
# False
# 71 82
# True
# 91 91
# False
# 8 17
# True
# 91 91
# False
# 8 18
# True
# 5 5
# False
# 12 13
# True
# 40 40
# True
# 0 0
# True
# 55 55
# False
# 99 98
# True
# 87 87
# False
# 96 98
# False
# 23 13
# True
# 52 52
# True
# 99 99
# True
# 55 55
# True
# 74 74
# True
# 32 32
# False
# 0 1
# True
# 26 26
# False
# 96 86
# True
# 10 10
# False
# 79 78
# False
# 54 55
# False
# 29 39
# True
# 41 41
# True
# 75 75
# True
# 9 9
# True
# 38 38
# True
# 12 12
# True
# 30 30
# True
# 10 10
# True
# 53 53
# True
# 43 43
# True
# 80 80
# True
# 90 90
# True
# 38 38
# True
# 23 23
# True
# 32 32
# True
# 96 96
# False
# 67 66
# True
# 22 22
# True
# 27 27
# False
# 90 81
# True
# 0 0
# True
# 12 12
# True
# 50 50
# False
# 59 58
# False
# 96 86
# True
# 22 22
# True
# 55 55
# False
# 67 68
# True
# 94 94
# True
# 79 79
# True
# 22 22
# False
# 91 81
# False
# 14 15
# False
# 99 98
# True
# 11 11
# True
# 9 9
# False
# 35 36
# True
# 59 59
# True
# 96 96
# True
# 44 44
# False
# 67 57
# True
# 74 74
# True
# 30 30
# False
# 79 78
# False
# 1 0
# True
# 99 99
# True
# 62 62
# False
# 27 28
# False
# 64 75
# True
# 18 18
# False
# 67 68
# False
# 1 0
# False
# 31 32
# False
# 0 1
# False
# 71 82
# True
# 37 37
# False
# 35 34
# False
# 20 10
# False
# 84 83
# True
# 34 34
# False
# 51 52
# True
# 51 51
# False
# 59 49
# False
# 0 1
# False
# 43 44
# True
# 4 4
# True
# 30 30
# True
# 51 51
# False
# 27 28
# True
# 94 94
# True
# 5 5
# True
# 47 47
# True
# 63 63
# False
# 27 28
# True
# 11 11
# False
# 96 95
# False
# 96 87
# True
# 37 37
# True
# 26 26
# True
# 64 64
# True
# 93 93
# True
# 34 34
# True
# 62 62
# True
# 60 60
# False
# 27 36
# False
# 84 83
# False
# 29 39
# True
# 1 1
# True
# 8 8
# False
# 34 44
# False
# 38 28
# True
# 42 42
# True
# 13 13
# True
# 96 96
# True
# 34 34
# False
# 64 65
# False
# 75 76
# True
# 60 60
# True
# 14 14
# False
# 43 44
# False
# 91 81
# True
# 4 4
# True
# 56 56
# False
# 79 87
# True
# 22 22
# True
# 15 15
# True
# 64 64
# False
# 35 36
# True
# 5 5
# True
# 43 43
# False
# 84 83
# True
# 32 32
# False
# 26 27
# True
# 43 43
# False
# 15 16
# True
# 12 12
# False
# 26 16
# False
# 55 56
# False
# 1 0
# True
# 67 67
# True
# 33 33
# False
# 26 25
# True
# 11 11
# False
# 64 63
# True
# 42 42
# False
# 23 24
# True
# 37 37
# True
# 14 14
# True
# 87 87
# False
# 64 65
# False
# 64 75
# False
# 79 77
# True
# 0 0
# False
# 47 57
# True
# 60 60
# True
# 8 8
# False
# 27 37
# True
# 3 3
# False
# 96 86
# True
# 75 75
# True
# 59 59
# False
# 79 89
# True
# 84 84
# True
# 24 24
# False
# 15 16
# True
# 36 36
# True
# 31 31
# True
# 40 40
# True
# 87 87
# False
# 0 10
# True
# 43 43
# True
# 10 10
# False
# 27 36
# True
# 10 10
# False
# 1 0
# True
# 53 53
# False
# 22 23
# True
# 22 22
# True
# 47 47
# True
# 82 82
# True
# 38 38
# False
# 71 81
# False
# 75 76
# False
# 71 72
# True
# 43 43
# False
# 99 98
# True
# 33 33
# False
# 31 30
# False
# 96 85
# True
# 15 15
# False
# 35 45
# False
# 18 28
# True
# 67 67
# True
# 25 25
# True
# 60 60
# True
# 50 50
# False
# 79 68
# False
# 96 95
# True
# 19 19
# True
# 82 82
# True
# 42 42
# False
# 79 88
# False
# 64 76
# True
# 13 13
# False
# 29 39
# False
# 26 16
# True
# 40 40
# True
# 51 51
# True
# 7 7
# False
# 35 36
# True
# 10 10
# False
# 37 28
# True
# 40 40
# False
# 79 78
# True
# 30 30
# True
# 99 99
# False
# 71 81
# False
# 99 98
# True
# 5 5
# False
# 38 48
# True
# 56 56
# True
# 67 67
# False
# 96 95
# False
# 26 17
# False
# 35 36
# False
# 79 78
# True
# 54 54
# True
# 43 43
# True
# 61 61
# False
# 99 88
# True
# 62 62
# True
# 80 80
# True
# 74 74
# False
# 50 60
# True
# 59 59
# True
# 40 40
# True
# 96 96
# False
# 96 95
# True
# 73 73
# True
# 52 52
# False
# 20 10
# True
# 3 3
# True
# 38 38
# True
# 18 18
# False
# 58 57
# False
# 84 83
# True
# 93 93
# True
# 26 26
# False
# 26 16
# False
# 2 1
# True
# 4 4
# True
# 34 34
# False
# 79 69
# True
# 18 18
# True
# 47 47
# False
# 55 56
# True
# 12 12
# False
# 67 57
# True
# 50 50
# True
# 8 8
# False
# 51 61
# False
# 20 30
# False
# 74 73
# False
# 27 26
# False
# 59 69
# True
# 30 30
# False
# 70 80
# False
# 79 78
# True
# 70 70
# False
# 90 80
# True
# 99 99
# True
# 64 64
# True
# 20 20
# True
# 29 29
# False
# 26 27
# False
# 30 40
# False
# 59 49
# True
# 47 47
# False
# 67 66
# True
# 70 70
# False
# 55 46
# False
# 44 45
# False
# 47 46
# True
# 84 84
# False
# 54 55
# False
# 64 63
# False
# 55 56
# True
# 64 64
# True
# 74 74
# False
# 51 61
# False
# 96 95
# True
# 40 40
# True
# 7 7
# False
# 8 9
# True
# 0 0
# True
# 96 96
# False
# 44 45
# True
# 34 34
# False
# 23 24
# True
# 5 5
# True
# 8 8
# True
# 18 18
# True
# 51 51
# True
# 51 51
# True
# 37 37
# True
# 70 70
# True
# 14 14
# False
# 41 51
# True
# 30 30
# True
# 25 25
# True
# 51 51
# True
# 53 53
# True
# 30 30
# True
# 23 23
# False
# 27 36
# False
# 84 74
# True
# 35 35
# False
# 59 49
# False
# 54 53
# True
# 59 59
# True
# 44 44
# True
# 23 23
# True
# 44 44
# False
# 26 36
# True
# 21 21
# False
# 91 92
# False
# 43 42
# False
# 84 83
# False
# 47 56
# False
# 91 92
# False
# 21 20
# True
# 99 99
# True
# 79 79
# False
# 64 75
# True
# 24 24
# True
# 99 99
# True
# 73 73
# False
# 71 72
# False
# 67 66
# True
# 54 54
# False
# 90 81
# True
# 47 47
# False
# 79 78
# True
# 80 80
# True
# 79 79
# True
# 63 63
# True
# 84 84
# False
# 41 42
# True
# 24 24
# True
# 21 21
# True
# 35 35
# False
# 84 94
# True
# 79 79
# True
# 5 5
# True
# 64 64
# False
# 3 4
# True
# 59 59
# True
# 27 27
# True
# 25 25
# False
# 44 45
# True
# 47 47
# True
# 22 22
# True
# 58 58
# False
# 79 69
# False
# 64 65
# True
# 12 12
# False
# 14 15
# True
# 15 15
# True
# 27 27
# True
# 1 1
# False
# 30 40
# True
# 18 18
# True
# 27 27
# False
# 64 63
# True
# 8 8
# True
# 34 34
# False
# 10 0
# False
# 27 28
# True
# 31 31
# True
# 84 84
# True
# 99 99
# False
# 10 0
# True
# 79 79
# True
# 12 12
# True
# 91 91
# False
# 21 11
# True
# 79 79
# False
# 0 10
# True
# 42 42
# False
# 74 85
# True
# 3 3
# True
# 54 54
# True
# 99 99
# False
# 79 89
# True
# 50 50
# True
# 61 61
# False
# 99 98
# True
# 64 64
# True
# 35 35
# False
# 67 57
# True
# 33 33
# True
# 84 84
# True
# 15 15
# True
# 37 37
# True
# 44 44
# False
# 8 17
# True
# 3 3
# True
# 67 67
# False
# 73 63
# True
# 55 55
# True
# 70 70
# False
# 2 1
# True
# 47 47
# True
# 40 40
# True
# 42 42
# True
# 19 19
# False
# 87 86
# False
# 71 81
# False
# 32 33
# False
# 27 37
# False
# 84 83
# True
# 61 61
# False
# 22 33
# True
# 96 96
# True
# 12 12
# True
# 26 26
# False
# 96 97
# True
# 34 34
# False
# 44 45
# True
# 26 26
# True
# 13 13
# True
# 0 0
# False
# 25 24
# False
# 96 97
# True
# 12 12
# True
# 60 60
# False
# 91 92
# False
# 9 19
# True
# 22 22
# True
# 41 41
# True
# 79 79
# False
# 24 25
# False
# 71 72
# True
# 72 72
# False
# 10 0
# True
# 5 5
# True
# 32 32
# True
# 12 12
# True
# 27 27
# False
# 38 28
# False
# 79 89
# True
# 25 25
# False
# 99 89
# True
# 44 44
# True
# 43 43
# True
# 0 0
# False
# 87 77
# False
# 38 39
# True
# 73 73
# False
# 79 69
# True
# 33 33
# True
# 64 64
# True
# 14 14
# False
# 67 66
# True
# 18 18
# True
# 31 31
# True
# 91 91
# True
# 36 36
# False
# 31 21
# True
# 26 26
# False
# 87 86
# False
# 62 72
# True
# 13 13
# False
# 79 88
# True
# 35 35
# True
# 34 34
# True
# 87 87
# False
# 6 16
# False
# 91 92
# True
# 12 12
# True
# 54 54
# False
# 75 86
# False
# 67 77
# True
# 34 34
# True
# 54 54
# True
# 22 22
# True
# 29 29
# False
# 96 95
# True
# 50 50
# True
# 50 50
# False
# 5 6
# False
# 67 68
# True
# 35 35
# True
# 29 29
# False
# 37 46
# True
# 87 87
# True
# 5 5
# True
# 7 7
# True
# 96 96
# False
# 23 34
# False
# 60 70
# True
# 82 82
# False
# 67 57
# False
# 42 52
# True
# 31 31
# False
# 96 97
# False
# 96 95
# True
# 43 43
# True
# 34 34
# False
# 60 70
# False
# 41 42
# True
# 37 37
# True
# 64 64
# False
# 12 13
# False
# 60 70
# False
# 0 11
# False
# 56 57
# False
# 96 85
# False
# 35 45
# False
# 55 66
# True
# 7 7
# True
# 7 7
# True
# 99 99
# True
# 23 23
# False
# 96 97
# True
# 29 29
# True
# 25 25
# True
# 54 54
# True
# 74 74
# True
# 43 43
# False
# 55 56
# True
# 20 20
# False
# 79 68
# False
# 91 92
# True
# 26 26
# False
# 79 69
# False
# 84 85
# True
# 5 5
# True
# 38 38
# True
# 59 59
# False
# 79 77
# False
# 12 11
# True
# 20 20
# True
# 50 50
# True
# 79 79
# False
# 96 98
# False
# 99 88
# False
# 29 19
# True
# 94 94
# True
# 1 1
# False
# 79 68
# False
# 38 28
# False
# 87 77
# False
# 35 45
# True
# 18 18
# True
# 22 22
# False
# 64 65
# False
# 55 66
# False
# 35 36
# True
# 4 4
# False
# 37 46
# False
# 67 57
# True
# 50 50
# False
# 46 45
# True
# 55 55
# False
# 71 81
# True
# 5 5
# False
# 71 72
# True
# 59 59
# True
# 35 35
# True
# 44 44
# True
# 26 26
# True
# 25 25
# True
# 93 93
# False
# 26 16
# True
# 26 26
# True
# 87 87
# False
# 52 53
# True
# 79 79
# False
# 79 78
# False
# 23 24
# True
# 91 91
# True
# 24 24
# False
# 96 95
# True
# 64 64
# True
# 55 55
# True
# 46 46
# True
# 18 18
# False
# 8 17
# False
# 47 58
# False
# 15 6
# False
# 44 45
# False
# 84 83
# False
# 27 36
# True
# 41 41
# True
# 20 20
# False
# 37 47
# False
# 67 77
# False
# 54 65
# False
# 32 33
# True
# 0 0
# True
# 29 29
# False
# 99 88
# False
# 7 17
# True
# 4 4
# True
# 53 53
# True
# 2 2
# True
# 41 41
# False
# 63 73
# False
# 64 65
# False
# 55 56
# False
# 79 77
# True
# 24 24
# True
# 7 7
# False
# 41 42
# True
# 91 91
# False
# 41 31
# False
# 38 48
# False
# 50 60
# False
# 23 24
# False
# 87 86
# True
# 14 14
# True
# 43 43
# False
# 71 72
# True
# 52 52
# False
# 64 65
# False
# 71 81
# True
# 52 52
# False
# 41 42
# True
# 19 19
# False
# 37 47
# False
# 55 56
# False
# 84 94
# True
# 34 34
# False
# 79 89
# False
# 38 49
# False
# 84 83
# True
# 64 64
# True
# 1 1
# True
# 7 7
# True
# 79 79
# True
# 14 14
# True
# 79 79
# True
# 22 22
# True
# 54 54
# True
# 54 54
# False
# 87 86
# True
# 14 14
# True
# 15 15
# False
# 96 85
# False
# 0 10
# False
# 1 0
# True
# 22 22
# False
# 27 28
# False
# 84 83
# False
# 6 16
# False
# 12 13
# True
# 60 60
# False
# 71 82
# False
# 41 42
# True
# 93 93
# False
# 0 1
# True
# 93 93
# False
# 84 83
# True
# 25 25
# True
# 5 5
# False
# 67 77
# False
# 71 72
# True
# 62 62
# False
# 56 66
# True
# 8 8
# False
# 12 11
# False
# 3 2
# True
# 8 8
# False
# 99 88
# True
# 35 35
# False
# 84 94
# True
# 15 15
# False
# 67 76
# True
# 87 87
# False
# 67 76
# False
# 87 86
# True
# 52 52
# True
# 93 93
# False
# 67 68
# False
# 99 89
# True
# 96 96
# True
# 43 43
# True
# 38 38
# False
# 71 81
# True
# 50 50
# False
# 8 9
# True
# 13 13
# True
# 42 42
# False
# 67 57
# True
# 90 90
# False
# 30 31
# False
# 79 69
# True
# 64 64
# False
# 99 88
# True
# 25 25
# False
# 64 63
# True
# 94 94
# True
# 21 21
# False
# 79 89
# True
# 50 50
# False
# 38 48
# True
# 11 11
# True
# 31 31
# True
# 8 8
# False
# 67 68
# True
# 10 10
# True
# 12 12
# False
# 22 33
# False
# 42 43
# True
# 23 23
# True
# 91 91
# False
# 71 82
# True
# 34 34
# False
# 96 95
# True
# 84 84
# False
# 84 85
# True
# 42 42
# False
# 35 36
# False
# 38 28
# True
# 99 99
# True
# 58 58
# True
# 87 87
# False
# 55 56
# True
# 41 41
# True
# 91 91
# True
# 23 23
# True
# 23 23
# True
# 59 59
# False
# 27 28
# False
# 0 11
# False
# 87 76
# False
# 27 37
# True
# 2 2
# False
# 75 76
# False
# 64 63
# False
# 71 72
# True
# 24 24
# True
# 50 50
# True
# 12 12
# True
# 99 99
# True
# 15 15
# False
# 79 78
# True
# 62 62
# False
# 56 57
# True
# 80 80
# False
# 0 10
# False
# 15 16
# True
# 27 27
# False
# 30 40
# True
# 15 15
# False
# 90 80
# True
# 21 21
# True
# 60 60
# True
# 84 84
# True
# 31 31
# False
# 79 69
# True
# 55 55
# True
# 20 20
# True
# 23 23
# False
# 47 46
# True
# 90 90
# True
# 84 84
# False
# 91 81
# False
# 50 51
# False
# 79 78
# True
# 79 79
# True
# 24 24
# False
# 18 17
# True
# 14 14
# True
# 90 90
# True
# 87 87
# True
# 6 6
# False
# 41 31
# True
# 51 51
# True
# 0 0
# True
# 80 80
# False
# 23 24
# True
# 35 35
# False
# 71 82
# False
# 1 0
# False
# 67 68
# False
# 79 88
# False
# 91 82
# True
# 93 93
# False
# 34 44
# False
# 75 76
# False
# 64 75
# True
# 55 55
# False
# 99 98
# False
# 94 93
# True
# 27 27
# True
# 18 18
# True
# 70 70
# True
# 27 27
# True
# 29 29
# True
# 33 33
# False
# 79 88
# False
# 52 53
# True
# 35 35
# True
# 32 32
# False
# 91 92
# True
# 60 60
# True
# 29 29
# True
# 32 32
# False
# 99 98
# False
# 23 13
# True
# 31 31
# False
# 96 97
# False
# 59 49
# False
# 38 47
# False
# 59 49
# False
# 50 60
# False
# 26 16
# False
# 27 17
# True
# 22 22
# True
# 19 19
# False
# 38 37
# True
# 80 80
# False
# 99 98
# False
# 99 89
# True
# 1 1
# True
# 91 91
# True
# 2 2
# True
# 21 21
# False
# 96 98
# False
# 84 83
# True
# 55 55
# True
# 1 1
# False
# 50 60
# True
# 71 71
# True
# 30 30
# True
# 31 31
# False
# 90 80
# True
# 63 63
# False
# 90 80
# True
# 51 51
# False
# 27 28
# True
# 55 55
# False
# 59 69
# True
# 62 62
# True
# 0 0
# True
# 37 37
# True
# 70 70
# False
# 87 76
# True
# 96 96
# True
# 54 54
# True
# 71 71
# False
# 23 24
# False
# 34 44
# False
# 51 52
# False
# 55 56
# False
# 32 33
# False
# 14 13
# True
# 40 40
# True
# 41 41
# False
# 44 45
# True
# 10 10
# True
# 15 15
# False
# 75 76
# True
# 34 34
# True
# 11 11
# True
# 7 7
# False
# 35 36
# True
# 55 55
# False
# 71 81
# True
# 2 2
# True
# 21 21
# False
# 96 85
# True
# 27 27
# True
# 70 70
# False
# 12 2
# True
# 82 82
# True
# 25 25
# True
# 9 9
# True
# 36 36
# True
# 22 22
# True
# 63 63
# True
# 54 54
# True
# 30 30
# True
# 50 50
# True
# 1 1
# True
# 21 21
# False
# 87 77
# True
# 80 80
# True
# 79 79
# False
# 12 2
# False
# 79 68
# True
# 93 93
# False
# 60 70
# False
# 79 78
# False
# 38 48
# True
# 72 72
# True
# 21 21
# True
# 37 37
# True
# 18 18
# False
# 96 95
# True
# 27 27
# True
# 63 63
# False
# 56 57
# True
# 70 70
# False
# 94 93
# True
# 37 37
# False
# 84 83
# False
# 15 16
# True
# 60 60
# False
# 27 28
# True
# 51 51
# False
# 70 80
# False
# 74 75
# True
# 52 52
# True
# 4 4
# False
# 79 88
# True
# 30 30
# True
# 47 47
# True
# 42 42
# True
# 79 79
# True
# 7 7
# True
# 24 24
# False
# 96 95
# True
# 62 62
# True
# 4 4
# False
# 96 97
# True
# 52 52
# True
# 35 35
# True
# 99 99
# False
# 79 69
# True
# 32 32
# True
# 10 10
# False
# 79 77
# False
# 47 48
# True
# 11 11
# True
# 3 3
# True
# 84 84
# True
# 13 13
# False
# 26 17
# False
# 75 76
# True
# 99 99
# True
# 19 19
# False
# 67 66
# False
# 0 1
# True
# 34 34
# False
# 63 73
# True
# 25 25
# False
# 84 83
# False
# 27 37
# True
# 47 47
# False
# 38 39
# True
# 71 71
# True
# 31 31
# False
# 52 53
# True
# 6 6
# False
# 64 75
# True
# 2 2
# True
# 96 96
# False
# 87 77
# True
# 24 24
# True
# 12 12
# True
# 52 52
# False
# 38 48
# False
# 84 93
# True
# 54 54
# False
# 91 81
# False
# 84 85
# True
# 25 25
# True
# 21 21
# True
# 33 33
# False
# 37 46
# True
# 38 38
# False
# 99 98
# False
# 21 11
# True
# 50 50
# True
# 14 14
# True
# 43 43
# True
# 12 12
# False
# 96 97
# False
# 79 69
# True
# 37 37
# False
# 45 46
# True
# 99 99
# False
# 99 98
# False
# 90 80
# True
# 42 42
# False
# 37 47
# False
# 41 42
# False
# 64 75
# True
# 87 87
# True
# 12 12
# True
# 25 25
# False
# 67 66
# True
# 71 71
# True
# 94 94
# True
# 8 8
# True
# 6 6
# True
# 35 35
# True
# 6 6
# False
# 87 86
# True
# 7 7
# True
# 84 84
# True
# 70 70
# False
# 99 98
# True
# 84 84
# True
# 27 27
# True
# 71 71
# True
# 62 62
# False
# 55 56
# True
# 15 15
# True
# 94 94
# True
# 96 96
# False
# 29 39
# False
# 62 72
# True
# 67 67
# True
# 35 35
# False
# 23 13
# True
# 93 93
# True
# 99 99
# True
# 15 15
# True
# 26 26
# True
# 62 62
# True
# 96 96
# False
# 5 6
# True
# 96 96
# True
# 1 1
# True
# 96 96
# True
# 8 8
# False
# 0 1
# True
# 42 42
# True
# 99 99
# False
# 55 56
# True
# 8 8
# True
# 7 7
# True
# 33 33
# True
# 14 14
# False
# 22 33
# False
# 38 48
# False
# 5 6
# True
# 19 19
# True
# 84 84
# True
# 74 74
# True
# 10 10
# False
# 96 85
# True
# 15 15
# True
# 26 26
# False
# 91 92
# True
# 96 96
# False
# 79 78
# True
# 99 99
# False
# 75 76
# True
# 75 75
# False
# 26 27
# True
# 84 84
# False
# 75 76
# True
# 77 77
# True
# 24 24
# False
# 26 17
# False
# 91 82
# False
# 46 45
# False
# 55 65
# True
# 41 41
# True
# 47 47
# False
# 35 46
# True
# 4 4
# False
# 26 36
# False
# 23 24
# True
# 34 34
# True
# 37 37
# False
# 87 86
# True
# 14 14
# False
# 84 74
# True
# 43 43
# False
# 79 78
# True
# 18 18
# True
# 27 27
# True
# 18 18
# False
# 87 77
# True
# 40 40
# True
# 20 20
# False
# 67 68
# True
# 42 42
# True
# 90 90
# True
# 55 55
# False
# 27 28
# False
# 71 72
# False
# 18 19
# False
# 26 17
# True
# 43 43
# True
# 33 33
# False
# 71 81
# True
# 90 90
# True
# 41 41
# False
# 56 57
# False
# 54 55
# True
# 62 62
# True
# 23 23
# True
# 75 75
# True
# 27 27
# True
# 21 21
# False
# 79 69
# False
# 35 36
# True
# 71 71
# False
# 4 5
# True
# 41 41
# False
# 91 92
# True
# 29 29
# True
# 93 93
# True
# 37 37
# True
# 43 43
# False
# 59 49
# True
# 20 20
# True
# 71 71
# True
# 79 79
# False
# 91 81
# True
# 21 21
# False
# 79 78
# False
# 35 45
# True
# 91 91
# True
# 90 90
# True
# 19 19
# True
# 44 44
# True
# 14 14
# True
# 25 25
# True
# 30 30
# True
# 52 52
# False
# 84 83
# False
# 90 80
# True
# 50 50
# False
# 79 88
# False
# 99 88
# False
# 38 47
# True
# 7 7
# False
# 47 57
# True
# 62 62
# False
# 14 15
# True
# 64 64
# False
# 4 14
# False
# 37 47
# True
# 91 91
# False
# 71 61
# True
# 34 34
# True
# 18 18
# False
# 29 39
# True
# 29 29
# False
# 46 45
# True
# 29 29
# True
# 43 43
# False
# 80 70
# True
# 80 80
# False
# 38 47
# False
# 87 85
# False
# 26 17
# True
# 23 23
# True
# 44 44
# True
# 43 43
# False
# 2 1
# False
# 67 77
# True
# 4 4
# True
# 75 75
# True
# 50 50
# True
# 11 11
# True
# 79 79
# False
# 91 92
# True
# 19 19
# True
# 90 90
# False
# 96 97
# True
# 58 58
# True
# 29 29
# False
# 96 87
# True
# 0 0
# False
# 74 73
# True
# 73 73
# True
# 63 63
# True
# 18 18
# True
# 53 53
# True
# 23 23
# True
# 42 42
# True
# 7 7
# False
# 94 95
# False
# 38 48
# False
# 91 82
# True
# 14 14
# True
# 14 14
# True
# 38 38
# True
# 7 7
# False
# 84 83
# True
# 31 31
# False
# 12 13
# True
# 99 99
# True
# 54 54
# True
# 9 9
# True
# 8 8
# True
# 42 42
# True
# 37 37
# False
# 79 68
# True
# 60 60
# True
# 30 30
# True
# 43 43
# False
# 96 86
# True
# 58 58
# False
# 32 33
# True
# 59 59
# True
# 29 29
# False
# 44 45
# False
# 38 48
# True
# 11 11
# True
# 73 73
# False
# 26 16
# False
# 50 40
# False
# 84 85
# True
# 52 52
# False
# 29 39
# True
# 50 50
# False
# 51 41
# True
# 31 31
# True
# 42 42
# False
# 87 86
# False
# 67 66
# True
# 40 40
# True
# 12 12
# True
# 55 55
# True
# 47 47
# False
# 23 24
# True
# 47 47
# False
# 96 85
# False
# 52 63
# False
# 23 13
# False
# 67 68
# True
# 37 37
# False
# 29 39
# False
# 27 28
# False
# 47 46
# False
# 67 66
# True
# 62 62
# True
# 42 42
# False
# 27 28
# True
# 47 47
# False
# 59 49
# True
# 35 35
# False
# 79 78
# False
# 30 20
# True
# 29 29
# True
# 51 51
# True
# 67 67
# True
# 9 9
# False
# 91 81
# True
# 19 19
# True
# 34 34
# True
# 12 12
# True
# 33 33
# True
# 23 23
# True
# 59 59
# True
# 79 79
# True
# 84 84
# True
# 44 44
# True
# 3 3
# True
# 26 26
# True
# 10 10
# False
# 79 89
# False
# 38 48
# False
# 56 57
# True
# 26 26
# True
# 12 12
# True
# 62 62
# True
# 96 96
# True
# 84 84
# True
# 38 38
# True
# 12 12
# True
# 8 8
# True
# 35 35
# True
# 24 24
# False
# 38 39
# False
# 8 9
# False
# 47 57
# True
# 32 32
# True
# 14 14
# False
# 38 48
# False
# 79 78
# True
# 79 79
# False
# 27 36
# True
# 21 21
# True
# 4 4
# True
# 55 55
# True
# 54 54
# True
# 25 25
# True
# 7 7
# True
# 80 80
# False
# 94 93
# True
# 84 84
# False
# 29 39
# True
# 43 43
# False
# 62 72
# False
# 8 17
# True
# 9 9
# True
# 21 21
# False
# 79 77
# False
# 96 87
# True
# 52 52
# True
# 41 41
# True
# 8 8
# False
# 84 73
# True
# 43 43
# False
# 91 92
# True
# 84 84
# True
# 67 67
# True
# 40 40
# False
# 35 36
# True
# 73 73
# True
# 15 15
# True
# 14 14
# True
# 22 22
# False
# 74 85
# True
# 18 18
# True
# 31 31
# True
# 33 33
# False
# 96 85
# True
# 42 42
# True
# 19 19
# True
# 51 51
# True
# 4 4
# True
# 14 14
# False
# 79 69
# True
# 34 34
# False
# 38 39
# True
# 50 50
# False
# 38 29
# True
# 20 20
# False
# 12 13
# False
# 20 30
# False
# 67 66
# True
# 44 44
# False
# 37 47
# True
# 6 6
# True
# 47 47
# False
# 64 65
# True
# 90 90
# False
# 43 33
# False
# 20 30
# True
# 40 40
# True
# 91 91
# True
# 42 42
# True
# 22 22
# False
# 75 76
# False
# 24 25
# False
# 5 6
# False
# 84 74
# False
# 96 95
# True
# 93 93
# True
# 1 1
# False
# 60 70
# True
# 50 50
# True
# 59 59
# True
# 58 58
# True
# 35 35
# False
# 75 76
# False
# 87 86
# True
# 91 91
# False
# 5 6
# True
# 67 67
# True
# 61 61
# True
# 38 38
# True
# 87 87
# True
# 18 18
# False
# 84 73
# False
# 96 98
# False
# 99 98
# True
# 52 52
# True
# 10 10
# True
# 25 25
# True
# 10 10
# True
# 20 20
# False
# 96 86
# True
# 4 4
# True
# 2 2
# True
# 52 52
# False
# 5 6
# True
# 33 33
# False
# 87 76
# True
# 3 3
# False
# 45 46
# True
# 91 91
# True
# 35 35
# False
# 84 94
# True
# 47 47
# True
# 54 54
# False
# 96 87
# True
# 24 24
# True
# 29 29
# False
# 3 13
# False
# 55 56
# False
# 87 86
# True
# 34 34
# False
# 64 65
# False
# 55 65
# False
# 71 72
# True
# 21 21
# True
# 41 41
# False
# 96 97
# True
# 25 25
# True
# 15 15
# True
# 3 3
# True
# 50 50
# True
# 14 14
# True
# 91 91
# True
# 67 67
# True
# 5 5
# False
# 38 48
# True
# 54 54
# True
# 90 90
# False
# 44 45
# False
# 59 49
# True
# 1 1
# False
# 55 56
# False
# 84 83
# True
# 94 94
# False
# 19 29
# True
# 50 50
# True
# 55 55
# True
# 60 60
# True
# 91 91
# False
# 96 85
# True
# 3 3
# False
# 74 73
# True
# 75 75
# False
# 79 77
# False
# 99 89
# False
# 90 80
# True
# 0 0
# True
# 90 90
# False
# 71 72
# False
# 79 68
# True
# 90 90
# True
# 34 34
# False
# 47 57
# False
# 0 11
# True
# 35 35
# False
# 96 97
# False
# 96 97
# False
# 79 89
# False
# 47 46
# False
# 96 95
# True
# 4 4
# False
# 3 13
# False
# 38 28
# True
# 31 31
# True
# 26 26
# True
# 51 51
# True
# 42 42
# True
# 46 46
# False
# 52 62
# False
# 38 49
# False
# 44 45
# True
# 22 22
# True
# 25 25
# False
# 84 82
# True
# 90 90
# False
# 55 65
# True
# 14 14
# True
# 75 75
# True
# 30 30
# True
# 91 91
# True
# 64 64
# False
# 71 72
# True
# 59 59
# True
# 51 51
# True
# 15 15
# False
# 96 97
# False
# 44 45
# False
# 67 68
# True
# 18 18
# True
# 94 94
# True
# 18 18
# True
# 31 31
# False
# 50 51
# True
# 10 10
# False
# 79 78
# False
# 8 18
# False
# 64 66
# True
# 4 4
# True
# 38 38
# False
# 79 89
# False
# 38 39
# False
# 79 68
# False
# 21 10
# False
# 87 88
# False
# 35 25
# True
# 96 96
# True
# 22 22
# False
# 99 88
# False
# 47 48
# True
# 7 7
# True
# 62 62
# False
# 32 33
# True
# 21 21
# False
# 11 21
# True
# 37 37
# True
# 15 15
# True
# 59 59
# True
# 15 15
# False
# 15 16
# True
# 64 64
# True
# 47 47
# False
# 99 98
# True
# 62 62
# True
# 31 31
# False
# 8 18
# True
# 11 11
# False
# 8 9
# True
# 41 41
# True
# 6 6
# False
# 10 0
# True
# 29 29
# True
# 20 20
# True
# 56 56
# True
# 70 70
# False
# 47 46
# True
# 38 38
# True
# 87 87
# False
# 79 88
# False
# 64 74
# True
# 9 9
# True
# 7 7
# True
# 71 71
# False
# 84 83
# False
# 7 8
# False
# 71 81
# True
# 27 27
# True
# 11 11
# True
# 4 4
# False
# 3 2
# False
# 37 28
# False
# 79 69
# False
# 60 70
# False
# 79 78
# False
# 2 1
# True
# 18 18
# False
# 79 89
# False
# 67 58
# True
# 60 60
# True
# 30 30
# True
# 54 54
# False
# 96 97
# False
# 64 65
# False
# 84 74
# False
# 99 88
# False
# 84 93
# True
# 2 2
# True
# 93 93
# True
# 61 61
# False
# 70 60
# True
# 91 91
# True
# 96 96
# True
# 2 2
# False
# 35 36
# True
# 23 23
# True
# 71 71
# True
# 15 15
# False
# 54 55
# True
# 34 34
# True
# 43 43
# True
# 90 90
# False
# 38 48
# False
# 73 74
# True
# 10 10
# True
# 96 96
# True
# 7 7
# True
# 93 93
# False
# 5 6
# True
# 90 90
# False
# 35 36
# False
# 59 49
# True
# 82 82
# True
# 7 7
# True
# 87 87
# True
# 67 67
# True
# 37 37
# False
# 8 7
# True
# 19 19
# True
# 74 74
# False
# 15 16
# True
# 42 42
# False
# 26 16
# True
# 23 23
# True
# 84 84
# False
# 55 56
# True
# 42 42
# False
# 99 88
# True
# 4 4
# False
# 59 49
# True
# 35 35
# True
# 87 87
# True
# 60 60
# True
# 26 26
# False
# 23 14
# True
# 52 52
# True
# 38 38
# True
# 40 40
# True
# 52 52
# False
# 84 74
# True
# 41 41
# True
# 23 23
# False
# 55 46
# False
# 84 74
# True
# 61 61
# False
# 96 85
# True
# 23 23
# True
# 50 50
# False
# 1 2
# False
# 54 53
# True
# 35 35
# True
# 64 64
# True
# 4 4
# False
# 84 85
# True
# 55 55
# True
# 32 32
# True
# 12 12
# False
# 99 89
# False
# 79 69
# False
# 7 17
# False
# 29 39
# False
# 67 58
# True
# 26 26
# True
# 44 44
# True
# 51 51
# False
# 15 16
# False
# 10 0
# True
# 93 93
# True
# 23 23
# True
# 27 27
# False
# 91 92
# False
# 67 76
# True
# 12 12
# False
# 2 3
# True
# 99 99
# False
# 96 95
# True
# 99 99
# True
# 14 14
# True
# 27 27
# True
# 80 80
# False
# 79 69
# True
# 22 22
# True
# 20 20
# True
# 99 99
# True
# 93 93
# True
# 93 93
# False
# 59 68
# False
# 67 68
# True
# 41 41
# True
# 70 70
# True
# 60 60
# True
# 26 26
# False
# 79 78
# True
# 84 84
# True
# 84 84
# False
# 56 57
# True
# 35 35
# False
# 35 36
# True
# 27 27
# True
# 42 42
# False
# 59 49
# False
# 54 53
# True
# 20 20
# True
# 23 23
# True
# 59 59
# False
# 79 69
# True
# 51 51
# False
# 44 45
# True
# 12 12
# True
# 27 27
# False
# 64 65
# True
# 44 44
# False
# 26 16
# True
# 15 15
# True
# 35 35
# True
# 87 87
# False
# 75 85
# True
# 5 5
# True
# 26 26
# False
# 79 78
# True
# 79 79
# False
# 67 57
# True
# 5 5
# True
# 12 12
# True
# 31 31
# False
# 96 87
# False
# 99 89
# False
# 38 28
# False
# 18 28
# False
# 96 97
# True
# 32 32
# False
# 84 93
# False
# 42 53
# False
# 56 57
# False
# 4 5
# True
# 20 20
# False
# 96 86
# False
# 75 85
# False
# 52 63
# False
# 38 39
# False
# 47 46
# False
# 56 66
# False
# 99 98
# False
# 90 80
# True
# 43 43
# False
# 34 44
# True
# 24 24
# True
# 58 58
# False
# 67 66
# False
# 79 69
# True
# 33 33
# True
# 40 40
# False
# 38 28
# False
# 1 2
# False
# 79 78
# True
# 18 18
# False
# 96 85
# True
# 62 62
# False
# 71 61
# False
# 99 98
# True
# 27 27
# False
# 67 68
# True
# 23 23
# True
# 12 12
# True
# 11 11
# False
# 91 92
# False
# 5 6
# True
# 58 58
# True
# 96 96
# False
# 75 76
# False
# 3 2
# True
# 27 27
# True
# 62 62
# False
# 27 26
# False
# 9 19
# False
# 35 45
# True
# 84 84
# False
# 64 74
# True
# 99 99
# True
# 31 31
# True
# 40 40
# True
# 87 87
# True
# 20 20
# False
# 44 45
# True
# 29 29
# False
# 79 89
# False
# 79 89
# False
# 84 83
# True
# 51 51
# True
# 72 72
# False
# 27 37
# False
# 87 86
# True
# 67 67
# True
# 31 31
# True
# 70 70
# True
# 9 9
# True
# 67 67
# True
# 50 50
# False
# 64 54
# False
# 96 95
# False
# 67 68
# False
# 79 78
# False
# 91 92
# True
# 32 32
# True
# 93 93
# True
# 40 40
# True
# 59 59
# False
# 40 30
# False
# 91 81
# True
# 26 26
# False
# 79 78
# False
# 38 48
# False
# 90 80
# True
# 53 53
# True
# 12 12
# True
# 71 71
# False
# 29 39
# True
# 90 90
# True
# 30 30
# False
# 96 86
# False
# 11 12
# False
# 96 86
# False
# 91 92
# False
# 31 32
# True
# 2 2
# False
# 38 39
# True
# 64 64
# False
# 91 81
# False
# 79 78
# False
# 87 86
# False
# 75 76
# True
# 91 91
# False
# 91 92
# True
# 11 11
# True
# 96 96
# False
# 32 33
# True
# 63 63
# False
# 79 88
# False
# 59 58
# False
# 87 86
# True
# 23 23
# False
# 47 46
# True
# 38 38
# False
# 38 48
# True
# 6 6
# False
# 67 68
# False
# 79 78
# True
# 4 4
# True
# 20 20
# True
# 5 5
# True
# 82 82
# False
# 96 97
# True
# 60 60
# False
# 47 58
# True
# 67 67
# False
# 79 89
# True
# 35 35
# False
# 55 56
# False
# 8 18
# False
# 67 76
# False
# 38 49
# False
# 21 11
# False
# 20 30
# False
# 87 86
# True
# 94 94
# False
# 96 95
# True
# 19 19
# False
# 32 33
# False
# 96 97
# True
# 75 75
# False
# 50 61
# True
# 8 8
# False
# 54 53
# False
# 67 66
# False
# 90 80
# False
# 79 78
# True
# 31 31
# True
# 41 41
# False
# 10 20
# True
# 51 51
# True
# 59 59
# False
# 43 42
# True
# 71 71
# True
# 45 45
# False
# 8 17
# False
# 38 48
# True
# 87 87
# True
# 2 2
# True
# 36 36
# True
# 82 82
# False
# 90 80
# False
# 62 72
# False
# 47 46
# False
# 71 61
# False
# 4 14
# True
# 96 96
# True
# 37 37
# True
# 33 33
# True
# 20 20
# True
# 91 91
# True
# 29 29
# True
# 87 87
# False
# 99 98
# True
# 32 32
# False
# 84 73
# False
# 79 69
# True
# 5 5
# False
# 94 93
# False
# 79 78
# True
# 43 43
# True
# 18 18
# False
# 79 78
# False
# 79 68
# True
# 96 96
# True
# 43 43
# True
# 93 93
# True
# 4 4
# True
# 74 74
# False
# 96 95
# True
# 7 7
# True
# 75 75
# False
# 29 39
# False
# 56 66
# True
# 62 62
# False
# 87 86
# False
# 67 66
# True
# 40 40
# False
# 96 95
# True
# 18 18
# False
# 35 36
# False
# 79 78
# True
# 64 64
# True
# 16 16
# True
# 54 54
# False
# 64 63
# False
# 99 88
# True
# 44 44
# True
# 15 15
# True
# 71 71
# False
# 59 58
# False
# 99 89
# False
# 47 57
# False
# 64 65
# False
# 84 94
# False
# 38 39
# True
# 33 33
# True
# 63 63
# False
# 37 27
# False
# 96 85
# True
# 50 50
# False
# 90 80
# True
# 59 59
# False
# 79 69
# False
# 1 0
# False
# 79 78
# False
# 38 47
# True
# 12 12
# True
# 12 12
# False
# 54 55
# False
# 59 68
# False
# 79 69
# True
# 51 51
# False
# 38 39
# True
# 3 3
# False
# 37 47
# True
# 84 84
# True
# 54 54
# True
# 34 34
# True
# 60 60
# True
# 63 63
# True
# 30 30
# True
# 5 5
# True
# 21 21
# True
# 55 55
# False
# 79 78
# False
# 26 25
# True
# 24 24
# True
# 60 60
# False
# 55 46
# True
# 32 32
# True
# 52 52
# False
# 96 86
# False
# 79 88
# False
# 26 17
# True
# 70 70
# True
# 19 19
# True
# 11 11
# True
# 75 75
# True
# 59 59
# True
# 99 99
# True
# 64 64
# False
# 96 95
# False
# 99 89
# False
# 90 80
# True
# 51 51
# False
# 26 17
# True
# 35 35
# True
# 20 20
# True
# 99 99
# True
# 90 90
# False
# 79 69
# False
# 21 11
# True
# 6 6
# False
# 4 5
# True
# 23 23
# False
# 19 28
# False
# 90 80
# True
# 38 38
# True
# 23 23
# True
# 37 37
# True
# 64 64
# True
# 60 60
# False
# 67 66
# False
# 51 61
# True
# 84 84
# True
# 27 27
# True
# 51 51
# True
# 53 53
# True
# 19 19
# True
# 93 93
# False
# 71 61
# True
# 52 52
# False
# 41 31
# False
# 87 88
# False
# 22 23
# True
# 23 23
# True
# 47 47
# True
# 26 26
# True
# 99 99
# True
# 52 52
# False
# 84 82
# True
# 90 90
# True
# 15 15
# False
# 79 78
# False
# 55 65
# True
# 30 30
# True
# 14 14
# False
# 32 33
# True
# 71 71
# True
# 14 14
# False
# 96 95
# True
# 2 2
# True
# 41 41
# True
# 64 64
# False
# 42 43
# False
# 67 66
# False
# 23 24
# True
# 99 99
# True
# 50 50
# False
# 79 78
# True
# 90 90
# True
# 51 51
# False
# 54 53
# False
# 37 28
# False
# 75 86
# True
# 47 47
# True
# 71 71
# True
# 9 9
# True
# 52 52
# False
# 87 86
# False
# 91 81
# False
# 96 95
# True
# 74 74
# False
# 67 77
# True
# 87 87
# True
# 13 13
# False
# 26 25
# False
# 30 40
# False
# 79 68
# True
# 25 25
# False
# 96 97
# True
# 30 30
# True
# 26 26
# True
# 11 11
# True
# 20 20
# False
# 29 49
# False
# 79 69
# True
# 35 35
# True
# 64 64
# True
# 11 11
# False
# 96 95
# False
# 99 98
# True
# 3 3
# True
# 42 42
# False
# 56 66
# False
# 64 74
# True
# 43 43
# False
# 75 76
# True
# 21 21
# True
# 35 35
# True
# 44 44
# True
# 99 99
# True
# 1 1
# True
# 11 11
# True
# 43 43
# True
# 59 59
# False
# 37 47
# False
# 38 49
# False
# 91 92
# False
# 56 57
# False
# 64 63
# True
# 32 32
# False
# 96 95
# True
# 31 31
# False
# 14 15
# True
# 21 21
# False
# 99 89
# True
# 26 26
# True
# 12 12
# True
# 29 29
# True
# 71 71
# True
# 99 99
# False
# 35 25
# True
# 96 96
# True
# 96 96
# False
# 44 54
# True
# 35 35
# False
# 8 17
# True
# 1 1
# True
# 31 31
# True
# 58 58
# True
# 9 9
# False
# 84 85
# False
# 29 19
# True
# 41 41
# True
# 55 55
# False
# 44 45
# False
# 84 93
# False
# 59 68
# True
# 62 62
# True
# 21 21
# False
# 96 86
# True
# 67 67
# False
# 7 17
# True
# 96 96
# True
# 43 43
# False
# 91 82
# True
# 58 58
# False
# 22 12
# True
# 71 71
# False
# 84 83
# False
# 55 56
# True
# 80 80
# True
# 10 10
# True
# 79 79
# True
# 27 27
# False
# 99 89
# True
# 12 12
# False
# 67 57
# False
# 79 78
# True
# 34 34
# True
# 26 26
# True
# 9 9
# True
# 20 20
# False
# 71 81
# False
# 5 6
# True
# 34 34
# False
# 75 77
# True
# 54 54
# True
# 62 62
# True
# 22 22
# False
# 8 17
# False
# 4 5
# False
# 37 46
# True
# 44 44
# True
# 41 41
# True
# 87 87
# True
# 30 30
# True
# 87 87
# True
# 71 71
# False
# 84 74
# False
# 91 82
# True
# 54 54
# False
# 79 68
# False
# 47 57
# True
# 84 84
# False
# 3 13
# False
# 30 40
# False
# 38 48
# False
# 79 88
# True
# 24 24
# True
# 24 24
# True
# 4 4
# True
# 7 7
# False
# 96 97
# True
# 75 75
# True
# 60 60
# False
# 38 48
# True
# 30 30
# False
# 71 72
# False
# 84 73
# True
# 0 0
# False
# 44 45
# False
# 29 39
# True
# 64 64
# True
# 9 9
# False
# 22 23
# False
# 67 68
# True
# 33 33
# True
# 13 13
# True
# 58 58
# True
# 93 93
# False
# 79 88
# False
# 79 77
# True
# 10 10
# False
# 8 7
# True
# 19 19
# False
# 16 17
# False
# 73 72
# False
# 8 17
# False
# 43 44
# True
# 87 87
# False
# 84 83
# False
# 29 39
# False
# 75 76
# True
# 24 24
# True
# 9 9
# True
# 44 44
# True
# 26 26
# False
# 8 18
# False
# 67 66
# True
# 51 51
# False
# 38 39
# True
# 26 26
# True
# 7 7
# True
# 47 47
# False
# 91 82
# True
# 62 62
# True
# 74 74
# True
# 33 33
# False
# 44 45
# True
# 52 52
# False
# 79 69
# False
# 67 77
# False
# 84 83
# False
# 4 5
# True
# 84 84
# True
# 54 54
# True
# 16 16
# False
# 74 75
# False
# 38 47
# True
# 71 71
# False
# 99 98
# True
# 2 2
# False
# 5 6
# False
# 43 44
# True
# 29 29
# False
# 55 56
# True
# 91 91
# False
# 63 62
# True
# 42 42
# True
# 35 35
# True
# 64 64
# True
# 59 59
# True
# 54 54
# False
# 20 30
# False
# 91 92
# True
# 60 60
# True
# 71 71
# True
# 41 41
# True
# 51 51
# False
# 4 3
# False
# 10 0
# True
# 63 63
# True
# 32 32
# True
# 64 64
# True
# 93 93
# False
# 71 72
# True
# 99 99
# False
# 93 92
# True
# 87 87
# False
# 56 57
# False
# 20 30
# True
# 64 64
# False
# 32 42
# False
# 96 85
# True
# 41 41
# True
# 34 34
# True
# 12 12
# False
# 37 36
# True
# 38 38
# True
# 5 5
# True
# 73 73
# True
# 12 12
# False
# 84 83
# False
# 20 21
# False
# 26 16
# True
# 91 91
# False
# 96 86
# False
# 99 89
# False
# 79 78
# False
# 99 89
# True
# 82 82
# True
# 29 29
# False
# 91 81
# True
# 43 43
# True
# 3 3
# False
# 47 46
# True
# 44 44
# False
# 44 54
# True
# 27 27
# True
# 52 52
# True
# 54 54
# False
# 8 9
# True
# 37 37
# False
# 79 89
# True
# 34 34
# True
# 84 84
# False
# 18 19
# True
# 32 32
# True
# 10 10
# True
# 29 29
# False
# 56 66
# False
# 84 85
# False
# 91 82
# False
# 38 49
# True
# 70 70
# True
# 7 7
# True
# 40 40
# True
# 23 23
# False
# 67 66
# True
# 54 54
# True
# 62 62
# False
# 21 22
# True
# 43 43
# True
# 37 37
# True
# 22 22
# False
# 96 97
# True
# 33 33
# False
# 23 13
# True
# 11 11
# False
# 96 97
# True
# 52 52
# True
# 62 62
# True
# 71 71
# False
# 59 58
# False
# 55 56
# False
# 38 49
# True
# 59 59
# True
# 40 40
# False
# 26 17
# False
# 94 95
# False
# 3 13
# False
# 93 92
# True
# 84 84
# True
# 80 80
# True
# 67 67
# True
# 50 50
# True
# 32 32
# True
# 79 79
# True
# 8 8
# True
# 99 99
# True
# 18 18
# True
# 27 27
# True
# 2 2
# False
# 84 85
# True
# 99 99
# False
# 96 95
# False
# 96 98
# False
# 96 95
# True
# 79 79
# True
# 59 59
# False
# 54 53
# True
# 1 1
# False
# 52 63
# False
# 12 13
# True
# 22 22
# False
# 64 65
# False
# 0 11
# False
# 12 13
# False
# 41 42
# True
# 84 84
# False
# 64 63
# True
# 15 15
# False
# 37 46
# True
# 13 13
# False
# 50 60
# False
# 50 40
# True
# 23 23
# True
# 51 51
# True
# 71 71
# False
# 67 66
# True
# 24 24
# False
# 38 49
# True
# 46 46
# False
# 90 80
# True
# 6 6
# True
# 11 11
# True
# 34 34
# True
# 38 38
# True
# 64 64
# False
# 27 28
# False
# 29 49
# True
# 0 0
# True
# 67 67
# True
# 25 25
# False
# 51 61
# True
# 55 55
# True
# 99 99
# True
# 35 35
# True
# 63 63
# True
# 1 1
# True
# 21 21
# False
# 47 57
# True
# 19 19
# True
# 0 0
# False
# 10 0
# False
# 71 72
# True
# 80 80
# False
# 87 77
# True
# 84 84
# True
# 4 4
# False
# 62 72
# False
# 37 46
# True
# 43 43
# True
# 5 5
# True
# 82 82
# True
# 59 59
# True
# 87 87
# False
# ...
# True
# 34 34
# True
# 42 42
# False
# 64 65
# False
# 0 10
# True
# 90 90
# True
# 31 31
# False
# 91 81
# True
# 6 6
# False
# 71 72
# True
# 12 12
# False
# 14 13
# True
# 6 6
# True
# 20 20
# True
# 84 84
# True
# 14 14
# True
# 93 93
# True
# 63 63
# True
# 10 10
# True
# 19 19
# True
# 84 84
# True
# 9 9
# True
# 94 94
# True
# 59 59
# False
# 87 86
# False
# 99 88
# False
# 38 48
# False
# 15 16
# False
# 32 33
# False
# 21 11
# True
# 18 18
# False
# 64 75
# False
# 35 45
# False
# 59 58
# False
# 55 46
# True
# 33 33
# False
# 99 88
# True
# 8 8
# True
# 38 38
# True
# 14 14
# True
# 71 71
# True
# 38 38
# False
# 59 49
# True
# 74 74
# False
# 96 86
# True
# 67 67
# True
# 10 10
# False
# 55 56
# False
# 84 73
# False
# 84 82
# False
# 99 89
# True
# 26 26
# False
# 38 49
# False
# 1 0
# False
# 74 85
# False
# 84 83
# False
# 59 49
# True
# 87 87
# False
# 26 27
# False
# 79 88
# False
# 59 48
# True
# 90 90
# True
# 33 33
# False
# 38 49
# False
# 51 62
# True
# 23 23
# True
# 8 8
# True
# 33 33
# False
# 47 57
# True
# 67 67
# True
# 74 74
# False
# 91 81
# False
# 87 77
# True
# 1 1
# True
# 91 91
# True
# 84 84
# True
# 53 53
# True
# 10 10
# True
# 54 54
# False
# 79 68
# False
# 64 53
# True
# 55 55
# False
# 84 83
# False
# 32 33
# True
# 22 22
# True
# 22 22
# False
# 79 69
# False
# 96 87
# False
# 38 48
# True
# 8 8
# True
# 34 34
# True
# 40 40
# True
# 12 12
# True
# 11 11
# True
# 11 11
# False
# 75 76
# False
# 47 57
# False
# 61 62
# False
# 38 29
# True
# 94 94
# True
# 20 20
# True
# 64 64
# False
# 71 61
# True
# 50 50
# False
# 84 85
# True
# 82 82
# True
# 1 1
# True
# 8 8
# True
# 96 96
# False
# 91 92
# False
# 27 28
# False
# 59 69
# True
# 20 20
# True
# 51 51
# True
# 64 64
# True
# 31 31
# False
# 35 36
# False
# 0 11
# True
# 9 9
# True
# 14 14
# True
# 26 26
# True
# 30 30
# True
# 71 71
# False
# 84 83
# True
# 34 34
# True
# 75 75
# True
# 42 42
# False
# 79 89
# True
# 91 91
# True
# 67 67
# True
# 33 33
# False
# 52 62
# True
# 79 79
# True
# 63 63
# True
# 58 58
# False
# 79 68
# True
# 64 64
# False
# 26 16
# True
# 79 79
# True
# 20 20
# True
# 8 8
# True
# 44 44
# True
# 26 26
# True
# 10 10
# True
# 64 64
# False
# 2 3
# True
# 75 75
# True
# 38 38
# False
# 55 65
# False
# 90 81
# True
# 24 24
# False
# 79 77
# False
# 35 36
# True
# 8 8
# False
# 3 2
# False
# 90 80
# True
# 67 67
# True
# 32 32
# False
# 26 17
# True
# 90 90
# True
# 5 5
# True
# 90 90
# False
# 47 46
# True
# 2 2
# False
# 79 69
# False
# 71 72
# True
# 30 30
# False
# 27 28
# True
# 32 32
# False
# 96 97
# False
# 84 74
# True
# 43 43
# False
# 7 6
# True
# 2 2
# True
# 35 35
# True
# 50 50
# True
# 35 35
# True
# 0 0
# False
# 79 77
# True
# 23 23
# True
# 29 29
# True
# 9 9
# False
# 96 95
# True
# 20 20
# False
# 59 69
# True
# 15 15
# True
# 43 43
# True
# 67 67
# False
# 79 78
# True
# 58 58
# True
# 47 47
# True
# 50 50
# True
# 8 8
# False
# 87 86
# True
# 63 63
# False
# 64 75
# True
# 90 90
# True
# 63 63
# False
# 84 85
# False
# 29 49
# False
# 56 57
# True
# 18 18
# False
# 38 48
# False
# 59 49
# True
# 60 60
# False
# 96 86
# True
# 53 53
# True
# 64 64
# True
# 13 13
# False
# 60 70
# False
# 34 44
# True
# 27 27
# True
# 11 11
# True
# 38 38
# True
# 93 93
# True
# 58 58
# True
# 55 55
# True
# 8 8
# True
# 64 64
# True
# 62 62
# False
# 90 80
# True
# 71 71
# True
# 82 82
# True
# 44 44
# False
# 73 72
# True
# 12 12
# True
# 3 3
# True
# 54 54
# True
# 41 41
# True
# 3 3
# True
# 20 20
# True
# 38 38
# False
# 79 89
# True
# 96 96
# False
# 84 94
# False
# 96 97
# True
# 26 26
# True
# 67 67
# False
# 8 9
# True
# 41 41
# False
# 43 53
# True
# 3 3
# False
# 23 13
# True
# 84 84
# False
# 79 78
# True
# 33 33
# True
# 60 60
# False
# 90 80
# True
# 60 60
# True
# 75 75
# True
# 51 51
# True
# 20 20
# True
# 23 23
# True
# 64 64
# False
# 22 23
# True
# 3 3
# True
# 91 91
# True
# 84 84
# True
# 52 52
# True
# 27 27
# True
# 9 9
# True
# 64 64
# True
# 15 15
# False
# 91 92
# True
# 53 53
# True
# 71 71
# True
# 33 33
# True
# 13 13
# True
# 16 16
# False
# 38 48
# False
# 64 65
# False
# 26 25
# True
# 5 5
# True
# 20 20
# False
# 54 55
# True
# 58 58
# False
# 64 65
# True
# 84 84
# True
# 2 2
# True
# 47 47
# True
# 15 15
# True
# 20 20
# True
# 51 51
# False
# 29 49
# False
# 59 49
# False
# 43 44
# False
# 44 54
# False
# 84 74
# False
# 79 78
# False
# 41 42
# False
# 84 94
# False
# 67 66
# False
# 63 73
# True
# 34 34
# False
# 29 39
# True
# 93 93
# True
# 0 0
# True
# 60 60
# False
# 79 88
# False
# 4 14
# False
# 20 30
# True
# 91 91
# True
# 79 79
# True
# 7 7
# True
# 12 12
# True
# 52 52
# True
# 33 33
# True
# 43 43
# False
# 27 28
# True
# 31 31
# True
# 41 41
# False
# 84 83
# True
# 42 42
# True
# 10 10
# False
# 79 69
# False
# 55 65
# False
# 79 89
# True
# 47 47
# True
# 31 31
# True
# 60 60
# False
# 71 81
# False
# 12 13
# True
# 23 23
# False
# 5 6
# False
# 91 92
# True
# 30 30
# False
# 38 29
# True
# 2 2
# True
# 71 71
# False
# 22 32
# True
# 35 35
# True
# 54 54
# True
# 10 10
# False
# 37 36
# True
# 14 14
# True
# 10 10
# True
# 53 53
# False
# 31 21
# True
# 9 9
# True
# 54 54
# False
# 73 72
# False
# 96 97
# True
# 4 4
# True
# 6 6
# True
# 13 13
# True
# 24 24
# True
# 31 31
# False
# 2 3
# True
# 67 67
# True
# 11 11
# False
# 79 78
# False
# 0 1
# False
# 37 38
# False
# 27 28
# True
# 93 93
# True
# 58 58
# False
# 37 46
# True
# 14 14
# True
# 18 18
# False
# 96 85
# True
# 24 24
# True
# 84 84
# False
# 8 9
# False
# 99 98
# False
# 37 46
# True
# 53 53
# True
# 79 79
# False
# 67 68
# True
# 15 15
# False
# 96 97
# False
# 50 60
# False
# 75 76
# False
# 99 98
# True
# 30 30
# False
# 99 89
# False
# 91 92
# False
# 79 69
# False
# 8 9
# True
# 70 70
# True
# 84 84
# True
# 26 26
# False
# 84 83
# True
# 15 15
# False
# 25 26
# True
# 46 46
# True
# 55 55
# False
# 8 17
# True
# 52 52
# True
# 41 41
# False
# 38 49
# False
# 87 88
# False
# 90 80
# True
# 54 54
# False
# 79 78
# False
# 91 92
# True
# 93 93
# False
# 67 77
# True
# 54 54
# False
# 43 33
# False
# 38 48
# True
# 50 50
# True
# 73 73
# True
# 32 32
# True
# 6 6
# False
# 96 97
# True
# 60 60
# True
# 51 51
# True
# 47 47
# True
# 19 19
# True
# 55 55
# True
# 60 60
# False
# 87 77
# True
# 18 18
# True
# 90 90
# True
# 11 11
# False
# 37 46
# True
# 31 31
# False
# 54 53
# True
# 64 64
# False
# 64 53
# False
# 91 92
# True
# 54 54
# False
# 64 65
# False
# 23 13
# False
# 79 78
# True
# 93 93
# True
# 80 80
# False
# 96 98
# False
# 84 83
# False
# 87 86
# False
# 96 97
# True
# 10 10
# True
# 50 50
# True
# 4 4
# True
# 37 37
# True
# 34 34
# False
# 90 80
# False
# 54 53
# False
# 4 5
# True
# 19 19
# False
# 54 64
# False
# 26 17
# True
# 53 53
# False
# 8 17
# True
# 12 12
# False
# 96 85
# False
# 27 36
# True
# 24 24
# False
# 99 88
# False
# 79 68
# True
# 47 47
# False
# 26 25
# True
# 75 75
# True
# 3 3
# True
# 96 96
# False
# 59 49
# True
# 13 13
# False
# 35 36
# True
# 84 84
# False
# 52 62
# True
# 64 64
# False
# 14 15
# True
# 20 20
# False
# 71 72
# True
# 73 73
# True
# 26 26
# True
# 52 52
# False
# 12 13
# False
# 38 39
# True
# 4 4
# False
# 84 94
# False
# 44 45
# False
# 84 74
# True
# 62 62
# True
# 38 38
# False
# 90 80
# False
# 29 49
# False
# 56 57
# False
# 8 17
# True
# 53 53
# True
# 5 5
# True
# 80 80
# True
# 99 99
# False
# 91 81
# False
# 64 65
# False
# 22 33
# True
# 42 42
# True
# 24 24
# False
# 87 76
# True
# 75 75
# False
# 96 98
# True
# 18 18
# False
# 75 76
# False
# 67 68
# True
# 37 37
# True
# 59 59
# True
# 19 19
# False
# 84 83
# False
# 11 22
# False
# 38 47
# True
# 21 21
# False
# 99 89
# True
# 53 53
# True
# 35 35
# False
# 41 42
# True
# 41 41
# False
# 8 7
# True
# 54 54
# True
# 3 3
# False
# 84 83
# True
# 34 34
# True
# 13 13
# False
# 7 17
# True
# 14 14
# True
# 87 87
# True
# 24 24
# True
# 55 55
# False
# 4 14
# False
# 64 74
# False
# 79 77
# True
# 70 70
# True
# 38 38
# True
# 8 8
# True
# 0 0
# True
# 64 64
# False
# 59 49
# True
# 59 59
# False
# 38 48
# True
# 71 71
# True
# 31 31
# True
# 80 80
# False
# 29 49
# True
# 38 38
# True
# 94 94
# True
# 33 33
# False
# 84 73
# True
# 79 79
# True
# 70 70
# True
# 7 7
# True
# 4 4
# True
# 56 56
# True
# 21 21
# True
# 15 15
# True
# 22 22
# True
# 44 44
# False
# 38 48
# True
# 94 94
# True
# 1 1
# True
# 96 96
# True
# 5 5
# False
# 79 78
# True
# 15 15
# True
# 42 42
# False
# 75 76
# True
# 22 22
# False
# 47 46
# True
# 27 27
# False
# 67 66
# False
# 19 9
# True
# 99 99
# False
# 27 37
# True
# 71 71
# False
# 55 56
# True
# 35 35
# False
# 96 95
# True
# 50 50
# False
# 43 53
# False
# 99 98
# True
# 21 21
# False
# 96 85
# True
# 52 52
# False
# 51 61
# False
# 23 24
# False
# 10 0
# False
# 55 45
# False
# 32 42
# False
# 70 80
# True
# 7 7
# False
# 4 5
# True
# 14 14
# True
# 23 23
# True
# 51 51
# False
# 60 70
# False
# 96 87
# False
# 0 11
# False
# 99 89
# False
# 38 37
# True
# 23 23
# False
# 9 19
# False
# 15 16
# False
# 38 47
# False
# 38 39
# True
# 7 7
# False
# 64 65
# True
# 54 54
# False
# 87 85
# False
# 38 48
# False
# 67 76
# True
# 31 31
# False
# 99 98
# False
# 22 23
# False
# 55 56
# True
# 79 79
# True
# 59 59
# True
# 37 37
# True
# 6 6
# True
# 64 64
# False
# 59 58
# True
# 32 32
# False
# 96 97
# False
# 7 17
# True
# 1 1
# True
# 22 22
# True
# 55 55
# False
# 37 46
# False
# 67 77
# False
# 84 83
# True
# 94 94
# True
# 74 74
# True
# 54 54
# True
# 12 12
# True
# 63 63
# True
# 47 47
# False
# 50 60
# True
# 6 6
# False
# 71 61
# False
# 8 18
# True
# 29 29
# False
# 87 77
# False
# 60 70
# True
# 20 20
# True
# 50 50
# True
# 27 27
# False
# 84 82
# False
# 79 89
# True
# 73 73
# True
# 2 2
# False
# 47 46
# False
# 55 65
# False
# 21 20
# True
# 32 32
# True
# 4 4
# True
# 30 30
# True
# 75 75
# False
# 54 53
# True
# 52 52
# True
# 91 91
# True
# 34 34
# True
# 74 74
# False
# 0 1
# True
# 14 14
# True
# 94 94
# True
# 32 32
# True
# 79 79
# False
# 59 49
# True
# 75 75
# False
# 55 65
# True
# 84 84
# True
# 25 25
# False
# 91 92
# True
# 93 93
# True
# 21 21
# False
# 15 16
# False
# 44 45
# True
# 6 6
# True
# 80 80
# True
# 8 8
# True
# 37 37
# False
# 26 16
# False
# 35 45
# True
# 63 63
# False
# 60 50
# False
# 37 28
# False
# 71 72
# False
# 67 58
# False
# 67 66
# True
# 6 6
# False
# 64 65
# False
# 79 78
# True
# 64 64
# True
# 91 91
# True
# 31 31
# False
# 38 28
# True
# 7 7
# True
# 64 64
# True
# 96 96
# False
# 15 16
# True
# 84 84
# False
# 59 58
# False
# 55 56
# True
# 79 79
# True
# 79 79
# False
# 55 56
# True
# 64 64
# True
# 94 94
# False
# 22 23
# False
# 27 28
# False
# 38 48
# True
# 74 74
# True
# 51 51
# True
# 32 32
# True
# 32 32
# True
# 5 5
# True
# 67 67
# True
# 43 43
# False
# 35 44
# True
# 4 4
# True
# 74 74
# True
# 4 4
# True
# 30 30
# True
# 56 56
# True
# 64 64
# True
# 44 44
# True
# 13 13
# False
# 84 94
# False
# 64 63
# True
# 52 52
# False
# 79 89
# True
# 32 32
# True
# 52 52
# False
# 96 95
# True
# 1 1
# True
# 31 31
# False
# 22 33
# False
# 38 48
# True
# 51 51
# False
# 47 46
# True
# 20 20
# False
# 43 42
# True
# 23 23
# True
# 63 63
# True
# 96 96
# False
# 38 48
# True
# 60 60
# False
# 38 48
# True
# 80 80
# True
# 35 35
# True
# 20 20
# False
# 4 5
# False
# 43 53
# True
# 34 34
# True
# 1 1
# False
# 43 42
# False
# 26 16
# False
# 32 42
# False
# 84 73
# True
# 40 40
# True
# 12 12
# True
# 63 63
# True
# 9 9
# True
# 74 74
# True
# 52 52
# False
# 94 95
# False
# 71 82
# False
# 64 74
# True
# 59 59
# False
# 14 15
# False
# 64 54
# True
# 44 44
# True
# 14 14
# False
# 96 97
# False
# 99 89
# False
# 84 83
# False
# 55 66
# True
# 71 71
# True
# 20 20
# False
# 84 73
# True
# 64 64
# True
# 87 87
# False
# 91 81
# False
# 37 28
# False
# 96 95
# True
# 71 71
# True
# 38 38
# True
# 54 54
# True
# 27 27
# False
# 44 45
# False
# 10 20
# False
# 7 16
# True
# 50 50
# True
# 84 84
# False
# 55 56
# True
# 61 61
# True
# 91 91
# False
# 75 76
# True
# 59 59
# True
# 38 38
# False
# 20 10
# True
# 31 31
# False
# 64 54
# True
# 32 32
# True
# 94 94
# True
# 60 60
# True
# 62 62
# True
# 11 11
# True
# 5 5
# True
# 29 29
# True
# 3 3
# True
# 7 7
# True
# 30 30
# True
# 94 94
# False
# 96 86
# False
# 26 16
# False
# 79 69
# False
# 29 39
# True
# 87 87
# True
# 54 54
# True
# 5 5
# True
# 24 24
# False
# 64 65
# True
# 25 25
# True
# 23 23
# False
# 79 77
# False
# 67 68
# True
# 34 34
# True
# 2 2
# False
# 71 72
# False
# 91 82
# True
# 62 62
# True
# 90 90
# False
# 44 45
# False
# 23 13
# True
# 38 38
# True
# 55 55
# True
# 9 9
# True
# 64 64
# True
# 11 11
# True
# 51 51
# False
# 91 81
# False
# 91 81
# False
# 79 89
# True
# 21 21
# False
# 38 49
# False
# 27 28
# True
# 37 37
# False
# 87 86
# True
# 87 87
# False
# 94 93
# False
# 99 89
# True
# 29 29
# False
# 96 97
# True
# 79 79
# False
# 79 89
# True
# 36 36
# False
# 60 70
# False
# 23 13
# True
# 38 38
# True
# 64 64
# True
# 58 58
# True
# 62 62
# False
# 44 45
# True
# 79 79
# False
# 84 83
# True
# 91 91
# True
# 82 82
# True
# 32 32
# False
# 37 47
# False
# 79 68
# True
# 23 23
# False
# 55 45
# True
# 3 3
# True
# 90 90
# True
# 41 41
# False
# 37 46
# True
# 41 41
# False
# 26 25
# True
# 60 60
# False
# 84 85
# False
# 26 25
# False
# 30 31
# False
# 8 17
# True
# 52 52
# False
# 37 36
# True
# 41 41
# True
# 14 14
# False
# 75 76
# False
# 55 66
# False
# 5 6
# True
# 29 29
# True
# 14 14
# False
# 35 36
# False
# 84 94
# True
# 59 59
# True
# 79 79
# False
# 44 45
# True
# 63 63
# False
# 96 97
# False
# 19 9
# False
# 79 78
# False
# 60 70
# True
# 25 25
# True
# 32 32
# False
# 27 36
# False
# 75 76
# False
# 50 60
# True
# 59 59
# True
# 43 43
# False
# 26 16
# True
# 93 93
# True
# 35 35
# False
# 84 73
# False
# 38 39
# True
# 96 96
# True
# 7 7
# True
# 50 50
# True
# 19 19
# False
# 29 39
# True
# 71 71
# False
# 79 88
# False
# 84 83
# True
# 70 70
# False
# 79 77
# True
# 96 96
# False
# 84 74
# False
# 59 68
# False
# 21 11
# False
# 8 18
# False
# 84 85
# True
# 29 29
# True
# 0 0
# True
# 24 24
# False
# 26 16
# False
# 56 57
# False
# 84 83
# True
# 32 32
# False
# 79 77
# True
# 58 58
# True
# 40 40
# False
# 37 36
# True
# 55 55
# False
# 10 0
# False
# 96 97
# True
# 59 59
# False
# 18 28
# True
# 34 34
# True
# 96 96
# True
# 71 71
# False
# 38 48
# True
# 71 71
# False
# 79 77
# False
# 29 39
# True
# 84 84
# True
# 79 79
# False
# 67 68
# False
# 37 47
# True
# 37 37
# True
# 5 5
# False
# 84 94
# True
# 31 31
# False
# 15 16
# True
# 11 11
# False
# 23 13
# True
# 44 44
# False
# 91 81
# False
# 84 73
# False
# 91 92
# True
# 52 52
# True
# 23 23
# False
# 38 28
# True
# 71 71
# True
# 93 93
# True
# 38 38
# False
# 94 93
# True
# 33 33
# True
# 59 59
# True
# 67 67
# True
# 91 91
# False
# 87 77
# True
# 71 71
# False
# 22 12
# False
# 51 61
# False
# 54 55
# False
# 79 78
# True
# 19 19
# True
# 23 23
# True
# 42 42
# True
# 34 34
# False
# 79 69
# False
# 26 25
# True
# 29 29
# True
# 50 50
# False
# 1 0
# True
# 20 20
# True
# 53 53
# True
# 25 25
# True
# 22 22
# True
# 79 79
# False
# 79 78
# False
# 41 42
# True
# 47 47
# True
# 7 7
# True
# 40 40
# False
# 35 34
# True
# 5 5
# True
# 7 7
# False
# 74 85
# True
# 21 21
# False
# 55 56
# True
# 15 15
# False
# 91 92
# True
# 43 43
# True
# 70 70
# False
# 52 62
# False
# 44 45
# True
# 31 31
# True
# 94 94
# True
# 91 91
# True
# 3 3
# True
# 82 82
# True
# 41 41
# False
# 96 95
# True
# 64 64
# True
# 67 67
# False
# 38 48
# True
# 15 15
# True
# 18 18
# False
# 99 88
# True
# 67 67
# True
# 55 55
# True
# 59 59
# False
# 38 28
# False
# 64 74
# True
# 67 67
# False
# 99 87
# False
# 75 76
# False
# 44 45
# False
# 84 73
# True
# 84 84
# False
# 87 86
# False
# 71 81
# True
# 91 91
# True
# 84 84
# True
# 12 12
# False
# 38 49
# False
# 71 72
# True
# 64 64
# True
# 42 42
# True
# 26 26
# True
# 24 24
# True
# 22 22
# True
# 71 71
# True
# 10 10
# True
# 87 87
# True
# 46 46
# True
# 26 26
# True
# 50 50
# False
# 99 88
# True
# 13 13
# True
# 67 67
# True
# 26 26
# False
# 91 81
# False
# 32 33
# True
# 21 21
# False
# 62 72
# True
# 8 8
# False
# 54 55
# True
# 34 34
# True
# 50 50
# False
# 27 17
# True
# 67 67
# True
# 51 51
# False
# 99 88
# True
# 37 37
# True
# 32 32
# False
# 99 97
# True
# 79 79
# False
# 35 46
# True
# 0 0
# False
# 61 62
# False
# 55 66
# True
# 32 32
# False
# 96 95
# True
# 64 64
# True
# 70 70
# True
# 59 59
# False
# 84 73
# True
# 22 22
# True
# 5 5
# False
# 96 95
# False
# 79 69
# True
# 41 41
# True
# 40 40
# False
# 73 74
# False
# 87 86
# False
# 42 52
# True
# 32 32
# True
# 38 38
# True
# 94 94
# False
# 91 81
# True
# 27 27
# True
# 87 87
# False
# 47 46
# False
# 54 53
# True
# 96 96
# True
# 63 63
# False
# 21 11
# True
# 3 3
# False
# 75 76
# True
# 64 64
# False
# 67 66
# False
# 29 39
# True
# 37 37
# True
# 31 31
# True
# 59 59
# True
# 35 35
# True
# 79 79
# True
# 40 40
# False
# 71 82
# True
# 79 79
# False
# 37 46
# True
# 32 32
# True
# 60 60
# False
# 55 45
# True
# 7 7
# True
# 4 4
# False
# 37 46
# False
# 7 6
# False
# 19 28
# True
# 9 9
# True
# 12 12
# True
# 51 51
# True
# 70 70
# False
# 96 85
# True
# 99 99
# True
# 59 59
# False
# 84 85
# False
# 84 93
# False
# 29 39
# False
# 44 45
# True
# 37 37
# False
# 91 81
# True
# 75 75
# True
# 54 54
# False
# 41 51
# False
# 64 63
# False
# 59 49
# True
# 54 54
# False
# 84 85
# True
# 41 41
# True
# 15 15
# False
# 47 48
# False
# 71 61
# True
# 74 74
# False
# 27 18
# True
# 61 61
# True
# 35 35
# True
# 55 55
# True
# 7 7
# False
# 26 27
# True
# 87 87
# True
# 6 6
# True
# 33 33
# True
# 43 43
# False
# 38 48
# False
# 55 65
# True
# 71 71
# True
# 84 84
# False
# 93 82
# False
# 43 44
# True
# 8 8
# True
# 1 1
# True
# 5 5
# False
# 37 36
# True
# 53 53
# False
# 45 46
# True
# 1 1
# True
# 14 14
# True
# 25 25
# True
# 96 96
# True
# 26 26
# True
# 47 47
# False
# 35 25
# True
# 99 99
# True
# 46 46
# True
# 71 71
# False
# 99 88
# True
# 21 21
# True
# 14 14
# False
# 55 66
# True
# 58 58
# False
# 67 77
# False
# 79 78
# False
# 79 88
# False
# 96 98
# False
# 79 78
# True
# 14 14
# False
# 96 97
# True
# 99 99
# True
# 79 79
# False
# 55 66
# True
# 27 27
# False
# 79 69
# True
# 79 79
# True
# 35 35
# True
# 63 63
# False
# 70 60
# True
# 27 27
# True
# 52 52
# True
# 0 0
# True
# 10 10
# True
# 94 94
# True
# 15 15
# False
# 84 94
# True
# 35 35
# False
# 84 83
# True
# 82 82
# False
# 0 11
# True
# 29 29
# True
# 18 18
# False
# 19 29
# False
# 21 11
# True
# 87 87
# True
# 52 52
# True
# 63 63
# True
# 29 29
# False
# 64 65
# False
# 20 10
# True
# 50 50
# True
# 29 29
# False
# 84 83
# True
# 60 60
# True
# 41 41
# True
# 5 5
# True
# 84 84
# True
# 26 26
# False
# 96 95
# False
# 38 49
# False
# 27 28
# True
# 51 51
# True
# 54 54
# True
# 4 4
# False
# 5 6
# False
# 35 36
# True
# 90 90
# True
# 53 53
# False
# 27 28
# True
# 60 60
# True
# 63 63
# False
# 96 95
# False
# 84 85
# False
# 79 78
# False
# 79 78
# False
# 71 61
# False
# 96 86
# False
# 18 17
# True
# 38 38
# False
# 27 17
# False
# 91 81
# True
# 14 14
# True
# 91 91
# False
# 18 19
# False
# 99 88
# True
# 67 67
# True
# 90 90
# True
# 3 3
# True
# 30 30
# False
# 35 36
# False
# 14 15
# True
# 50 50
# False
# 67 77
# True
# 2 2
# True
# 8 8
# False
# 99 98
# False
# 35 36
# False
# 71 81
# False
# 96 95
# False
# 87 77
# False
# 91 92
# True
# 44 44
# True
# 55 55
# False
# 75 76
# True
# 71 71
# False
# 44 45
# False
# 35 46
# False
# 38 39
# False
# 44 54
# True
# 67 67
# True
# 29 29
# True
# 44 44
# True
# 18 18
# True
# 25 25
# False
# 71 61
# True
# 43 43
# False
# 23 24
# False
# 58 57
# True
# 20 20
# True
# 71 71
# True
# 53 53
# True
# 7 7
# False
# 96 85
# True
# 55 55
# False
# 24 25
# True
# 73 73
# True
# 40 40
# False
# 87 77
# True
# 27 27
# True
# 50 50
# False
# 84 85
# True
# 26 26
# False
# 84 74
# False
# 96 97
# False
# 11 21
# False
# 52 51
# False
# 20 30
# True
# 73 73
# False
# 38 49
# False
# 71 72
# False
# 71 72
# False
# 8 17
# True
# 38 38
# False
# 7 17
# True
# 38 38
# True
# 80 80
# True
# 2 2
# False
# 91 81
# True
# 34 34
# False
# 27 36
# True
# 38 38
# False
# 99 98
# False
# 99 98
# False
# 59 58
# True
# 67 67
# False
# 96 87
# False
# 96 94
# False
# 99 98
# False
# 87 77
# True
# 67 67
# False
# 84 94
# False
# 43 44
# False
# 96 97
# True
# 54 54
# True
# 90 90
# False
# 59 58
# False
# 96 97
# True
# 34 34
# True
# 38 38
# True
# 74 74
# True
# 91 91
# True
# 2 2
# True
# 5 5
# False
# 55 46
# True
# 37 37
# True
# 84 84
# True
# 22 22
# False
# 96 95
# True
# 21 21
# True
# 20 20
# True
# 10 10
# True
# 53 53
# False
# 91 81
# False
# 96 95
# False
# 84 83
# False
# 9 19
# False
# 38 47
# False
# 90 80
# True
# 33 33
# True
# 7 7
# True
# 2 2
# True
# 50 50
# True
# 84 84
# True
# 8 8
# True
# 0 0
# True
# 42 42
# True
# 34 34
# False
# 64 66
# True
# 67 67
# True
# 59 59
# False
# 38 47
# False
# 26 17
# False
# 96 97
# True
# 51 51
# True
# 32 32
# True
# 5 5
# False
# 84 83
# True
# 91 91
# True
# 31 31
# True
# 62 62
# False
# 79 69
# True
# 34 34
# False
# 64 65
# False
# 34 24
# True
# 93 93
# False
# 96 95
# False
# 23 24
# True
# 14 14
# True
# 18 18
# False
# 47 46
# True
# 94 94
# True
# 41 41
# True
# 9 9
# True
# 70 70
# True
# 93 93
# False
# 79 89
# True
# 4 4
# True
# 13 13
# True
# 35 35
# True
# 75 75
# True
# 40 40
# True
# 44 44
# True
# 38 38
# False
# 91 81
# True
# 3 3
# True
# 51 51
# True
# 37 37
# False
# 0 11
# False
# 96 97
# False
# 60 70
# True
# 31 31
# False
# 75 76
# True
# 64 64
# True
# 47 47
# True
# 7 7
# False
# 44 45
# True
# 0 0
# False
# 90 80
# True
# 21 21
# False
# 96 95
# False
# 99 98
# False
# 26 16
# True
# 26 26
# True
# 18 18
# True
# 29 29
# False
# 55 56
# False
# 47 46
# True
# 63 63

# %%
y_test_coordinates = []
for el in y_test:
    for i,value in enumerate(el):
        if value == 1.:
            y_test_coordinates.append(i)
